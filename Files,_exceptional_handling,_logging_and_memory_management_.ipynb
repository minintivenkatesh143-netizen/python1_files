# %% [markdown]
# # Files, exceptional handling, logging andmemory management

# %% [markdown]
# **Q1.What is the difference between interpreted and compiled languages?**
#
# **1.Compiled Languages:**
#
# - **Definition**: Source code is translated into machine code (binary instructions) by a compiler before execution.
#
# - **Execution**: The computer runs the compiled binary directly.
#
# **EXAMPLES**: C, C++, Rust, Go.
#
# - **ADVANTAGES**:
#
# - Faster execution (since it’s already machine code).
#
# - Better optimization by the compiler
#
# - **DISADVANTAGE**:
#
# - Compilation step required before running.
#
# - Less flexible for quick testing or scripting.
#
#
# **2.Interpreted Languages**:
#
# - **Definition**: Source code is executed line by line by an interpreter at runtime.
#
# - **Execution**: No separate compilation step; interpreter directly runs the code.
#
# **EXAMPLES**: Python, JavaScript, Ruby, PHP.
#
# - **ADVANTAGE**:
# - Easier to test and debug (run immediately without compiling).
#
# - More portable (interpreter handles machine differences).
#
# - **DISADVANTAGE**:
# - Slower execution (interpreter translates while running).
#
# - More memory usage.

# %% [markdown]
# **Q2.What is exception handling in Python?**
# - Python provides the try-except block to catch and handle exceptions.
# - **Basic Syntax**

# %%
try:
    # Code that may cause an error
    x = 10 / 0
except ZeroDivisionError:
    # Code to handle the error
    print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %% [markdown]
# **COMMON KEYWORDS**
# - **1.try** – block where you write risky code.
#
# - **2.except** – block to handle the exception.
#
# - **3.else** – runs if no exception occurs.
#
# - **4.finally** – always runs (for cleanup tasks).
#
#
# **EXAMPLE:**

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Please enter a valid number.")
else:
    print("Result is:", result)
finally:
    print("Execution completed.")
# Out:
# Enter a number: 10
# Result is: 1.0
# Execution completed.

# %% [markdown]
# **Q3.What is the purpose of the finally block in exception handling?**
# - The finally **block in Python exception handling** is used to write code that will always run, no matter what happens in the try or **except blocks.**
#
# - In Python exception handling, the **finally block** is used to write code that must run no matter what happens—whether an **exception** occurs or not.
#
# **Purpose of the finally block**
# - It ensures cleanup actions are performed.
#
# - Runs always:
#
# - If no exception occurs ✅
#
# - If an exception occurs and is handled ✅
#
# - If an exception occurs and is not handled ✅
#
# **SYNTAX:**

# %%
f = None  # Initialize f to None
try:
    # risky code
    f = open("test.txt", "r")
    data = f.read()
except FileNotFoundError:
    print("File not found.")
finally:
    print("Closing file (if opened).")
    if f is not None:  # Check if f was successfully opened
        f.close()
# Out:
# File not found.
# Closing file (if opened).

# %% [markdown]
# **KEY USES CASES:**
# - **1.Releasing resources** (closing files, network connections, databases).
#
# - **2.Cleanup tasks** (deleting temporary files, rolling back transactions).
#
# - **3.Guaranteed execution** (logging, printing status, ending processes).
#
# **EXAMPLE:**

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ZeroDivisionError:
    print("Cannot divide by zero.")
finally:
    print("This will always execute!")
# Out:
# Enter a number: 2
# This will always execute!

# %% [markdown]
# **Q4.What is logging in Python?**
# - Python, logging is the process of recording information (messages, warnings, errors, etc.) about a program’s execution.
#
# Instead of just using print(), Python’s built-in logging module provides a flexible way to track events and debug programs.
#
#
# - | Level      | Purpose                                                 |
# | ---------- | ------------------------------------------------------- |
# | `DEBUG`    | Detailed diagnostic information (for developers).       |
# | `INFO`     | General events showing the program is working.          |
# | `WARNING`  | Something unexpected happened, but program still works. |
# | `ERROR`    | A serious issue that prevented a function from working. |
# | `CRITICAL` | A very severe error — program may not continue.         |
#
#
# **BASIC EXAMPLE**:

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.DEBUG)

logging.debug("This is a debug message.")
logging.info("Program started successfully.")
logging.warning("Low disk space warning!")
logging.error("File not found error.")
logging.critical("System crash!")
# Out:
# WARNING:root:Low disk space warning!
# ERROR:root:File not found error.
# CRITICAL:root:System crash!

# %% [markdown]
# **Q5 What is the significance of the**   __ del__  **method in Python?**
# - In Python, the__del__method is a destructor method.
# It is automatically called when an **object** is about to be destroyed (i.e., when it is no longer in use and is being garbage collected).
#
# - **Significance of** __del__
# - **1.CLEANUP TASK**:
#
# - Used to release resources before an object is deleted.
#
# - Example: closing files, releasing network connections, freeing memory.
#
# - **2.FINAL STEP BEFORE DELETION**
# - Acts like a “goodbye” function for the object.
#
# - **3.GARBAGE COLLECTION:**
# - Python automatically destroys objects when they are no longer referenced.
#
# - __del__runs just before the object is removed from memory.

# %% [markdown]
# **Q6.What is the difference between import and from ... import in Python?**
# - **1. IMPORT**
# - **SYNTAX:**
#
#   import module_name
#
# - This imports the whole module.
#
# - To use something from that module, you must reference it with the module name (dot notation
#
# **EXAMPLE**:

# %%
import math

print(math.sqrt(16))   # must use math. prefix
print(math.pi)

# %% [markdown]
# 2. **FROM ...IMPORT-**
#
#     from module_name import specific_name
# - This imports only specific functions, classes, or variables from a module.
#
# - You can use them directly without the module prefix.
#
# **EXAMPLE**:

# %%
from math import sqrt, pi

print(sqrt(16))   # directly use sqrt
print(pi)

# %% [markdown]
# - **KEY DIFFRENCES**:
#
# | Feature     | `import`                       | `from ... import`                             |
# | ----------- | ------------------------------ | --------------------------------------------- |
# | Imports     | Whole module                   | Specific functions, classes, or variables     |
# | Access      | Must use `module_name.item`    | Use directly without prefix                   |
# | Memory      | May load more than needed      | Loads only requested names                    |
# | Readability | Clearer where things come from | Shorter, but can be confusing if many imports |

# %% [markdown]
# **Q7.How can you handle multiple exceptions in Python?**
# - In Python, you can handle multiple exceptions in a few different ways depending on your use case.
# - ✅ 1. **Multiple except blocks**

# %%
try:
    x = int("abc")   # ValueError
    y = 10 / 0       # ZeroDivisionError
except ValueError:
    print("Invalid conversion to integer")
except ZeroDivisionError:
    print("Division by zero not allowed")

# %% [markdown]
#  ✅ **2. Catch multiple exceptions in one block (tuple)**
# - If multiple exceptions should be handled the same way, you can group them in a tuple:

# %%
try:
    x = int("abc")   # ValueError
    y = 10 / 0       # ZeroDivisionError
except (ValueError, ZeroDivisionError) as e:
    print(f"An error occurred: {e}")

# %% [markdown]
#  ✅ **3. Generic except for all exceptions**
#  - Catch any exception (not recommended unless you really need it):

# %%
try:
    x = int("abc")
    y = 10 / 0
except Exception as e:
    print(f"Unexpected error: {e}")

# %% [markdown]
# ✅ **4. else and finally with multiple exceptions**
# - You can also **combine else (runs if no error occurs) and finally (always runs)**

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Please enter a valid number.")
except ZeroDivisionError:
    print("Cannot divide by zero.")
else:
    print(f"Result: {result}")
finally:
    print("Execution finished.")

# %% [markdown]
# **Q8. What is the purpose of the with statement when handling files in Python?**
#
# -  **Purpose of with in file handling**"
# - It ensures that the file is properly closed after its suite finishes, even if an exception occurs.
#
# - You don’t need to explicitly call file.close().
#
# - It makes the code cleaner, safer, and more readable.
#
# ✅ **EXAMPLE WITHOUT** with

# %%
file = open("example.txt", "r")
try:
    data = file.read()
    print(data)
finally:
    file.close()   # Must ensure file is closed manually

# %% [markdown]
# ✅ **EXAMPLE WITH** with

# %%
with open("example.txt", "r") as file:
    data = file.read()
    print(data)
# file is automatically closed here, no need for file.close()

# %% [markdown]
# - **KEY BENIFITS**:
#
# - Automatic resource cleanup – file closes automatically.
#
# - Less error-prone – no risk of forgetting file.close().
#
# - Cleaner code – fewer lines and better readability.
#
# - Works with other resources too (like sockets, database connections, locks).

# %% [markdown]
# **Q9.What is the difference between multithreading and multiprocessing**?
# - **MULTITHREADING**:
# - **Definition**: Running multiple threads (lightweight processes) within the same process.
#
# - **Memory**: All threads share the same memory space.
#
# - **Best for**: I/O-bound tasks (like file I/O, network requests, waiting for user input).
#
# - **In Python**: Limited by the Global Interpreter Lock (GIL), so only one thread executes Python bytecode at a time.
#
# - **EXAMPLE USE CASES**:
# - Downloading multiple web pages at once.
#
# - Handling multiple clients in a chat server.
#
# - Reading/writing files concurrently.
#
# - **MULTIPROCESSING**:
# - **Definition**: Running multiple independent processes, each with its own Python interpreter and memory space.
#
# - **Memory**: Processes do not share memory (need inter-process communication to share data).
#
# - **Best for**: CPU-bound tasks (like calculations, data processing, heavy computation).
#
# - **In Python**: Bypasses the GIL since each process has its own interpreter.
#
# **EXAMPLE USES CASES:**
# - Image/video processing.
#
# - Machine learning model training.
#
# - Large mathematical computations.

# %% [markdown]
# - **KEY DIFFERENCES**:
# | Feature        | Multithreading 🧵          | Multiprocessing ⚡                       |
# | -------------- | -------------------------- | --------------------------------------- |
# | Execution Unit | Threads within one process | Separate processes                      |
# | Memory         | Shared memory space        | Independent memory spaces               |
# | Overhead       | Low (lightweight)          | High (process creation is heavy)        |
# | Best for       | I/O-bound tasks            | CPU-bound tasks                         |
# | GIL in Python  | Affects performance        | Not affected (each has own interpreter) |
# | Communication  | Easy (shared variables)    | Harder (requires IPC: pipes, queues)    |

# %% [markdown]
# **Q10.What are the advantages of using logging in a program?**
#
#  **ADVANTAGE OS USING LOGGING**:
#
# **1.Better than** print() **for debugging**
# - Print() is simple, but not flexible.
#
# - Logging provides **structured, configurable, and professional debugging** information.
#
# **2.Different log levels (severity)**
# - ogging allows categorizing messages as:
#
# - DEBUG – detailed info (useful for developers)
#
# - INFO – confirmation that things work as expected
#
# - WARNING – something unexpected happened, but program still runs
#
# - ERROR – a serious issue, program might fail in part
#
# - CRITICAL – very severe error, program may crash
#
# **3.Configurable output**:
# - Logs can be written to:
#
# - Console
#
# - Files
#
# - Remote servers
#
# - Databases
#
# **4.Persistent record of events**
# - Unlike print(), which disappears after execution, logs can be stored in files for **future analysis**.
#
# - Helps in debugging issues reported later.
#
# **5.Easy debugging in production**:
#
# - In production, you often can’t use print() freely.
#
# - Logging lets you capture what happened in real-time, without interrupting

# %% [markdown]
# **EXAMPLE**:

# %%
import logging

# Configure logging
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filename="app.log",  # logs to a file instead of console
    filemode="w"
)

logging.debug("This is a debug message")
logging.info("Application started")
logging.warning("Low disk space")
logging.error("File not found")
logging.critical("System crash")

# %% [markdown]
# **Q11.What is memory management in Python?**
#
# **MEMORY MANAGEMENT IN PYTHON**:
# - Memory management in Python means **how Python allocates, uses, and frees memory** for variables, objects, and data structures while the program runs.
#
# Python does this automatically through its **memory manager** and **garbage collector**.
#
# - **KEY COMPONENTS**:
# - **1.Private Heap Space**
# - All Python objects and data are stored in a **private heap**.
#
# - This memory is managed by Python’s **memory manager**, not directly accessible to programmers.
#
# - **2.Memory Manager**:
# - Responsible for **allocating** and **deallocating memory for objects**.
#
# - Keeps track of all **Python** objects.
#
# - **3.Garbage Collection**:
#
# - Python uses **automatic garbage collection to free memory** that is no longer in use.
#
# - The main **technique** is reference counting:
#
# - Each object keeps track of how many references point to it.
#
# - When the reference count drops to **zero → object is deleted.**
#
# - For circular references (objects referencing each other), **Python also uses a cyclic garbage collector**
#
# - **4.Dynamic Typing**:
#
# - Since Python is **dynamically typed, variables don’t have fixed memory sizes.**
#
# - The interpreter decides **memory allocation at runtime.**
#
# - **5.Memory Pools (PyMalloc**):
#
# - For efficiency, Python maintains pools of memory blocks.
#
# - This reduces overhead of requesting memory from the operating system repeatedly.
#
#
# **EXAMPLE**:

# %%
import sys

a = [1, 2, 3]
b = a    # another reference to the same list
print(sys.getrefcount(a))  # shows how many references exist

# %% [markdown]
# **Q12.What are the basic steps involved in exception handling in Python?**
# - When writing code in Python, you use try-except blocks to handle exceptions. The main steps are:
# - ✅ **1. Wrap risky code in a try block:**
# - Place the code that might raise an exception inside a try block.

# %%
try:
    num = int("abc")  # risky code (will raise ValueError)

# %% [markdown]
# ✅ **4. (Optional) Use finally block**:
#
# - Code inside finally runs always, whether an exception occurred or not.
#
# - Useful for cleanup (e.g., closing files, releasing resources).

# %%
try:
    file = open("data.txt", "r")
    content = file.read()
except FileNotFoundError:
    print("File not found!")
else:
    print("File read successfully.")
finally:
    print("Closing file...")
    file.close()

# %% [markdown]
# - **SUMMAY OF STEPS**
#
# - try → Write risky code.
#
# - except → Handle the error if it occurs.
#
# - else (optional) → Run code if no error happened.
#
# - finally (optional) → Run cleanup code (always executes).

# %% [markdown]
# **Q13.Why is memory management important in Python?**
#
# **1. EFFICIENT USE OF RESOURCES**:
#
# - Computers have limited RAM.
#
# - Good memory management ensures Python programs don’t consume more memory than necessary.
#
# **2.PREVENTS MEMORY LEAKS**:
# - If unused objects are not freed, they keep occupying memory → leading to memory leaks.
#
# - Python’s garbage collector automatically frees memory of objects that are no longer needed.
#
# **3.IMPROVE PERFORMANCE**:
# - Proper memory handling avoids slowdowns caused by unnecessary memory usage.
#
# - Example: If memory is cluttered with unused objects, Python spends extra time managing them.
#
# **4.AUTOMATIC GARBAGE COLLECTION**:
# - Python handles most memory cleanup for you (via reference counting + cyclic garbage collector).
#
# - Developers can focus on logic instead of manually managing memory (like in C/C++).
#
# **5.SUPPORT DYNAMIC TYPING**:
# - Python variables can change type at runtime (x = 10 → later x = "hello").
#
# - Memory management ensures the old object’s memory can be reclaimed safely.
#
# **6.SCALABILITY OF APPLICATION**:
# - arge programs (web apps, ML models, data processing) rely on efficient memory usage.
#
# - Poor memory management could crash programs with "Out of Memory" errors.
#
# **7.THREAD & PROCESSSAFETY**:
# - Python’s memory manager ensures memory is handled safely even in multithreading and multiprocessing scenarios.

# %% [markdown]
# **EXAMPLE**:

# %%
a = [1, 2, 3]   # list created
b = a           # another reference to the same list
del a           # removes one reference, but object still exists because b refers to it
print(b)        # [1, 2, 3]

# %% [markdown]
# **Q14.What is the role of try and except in exception handling?**
# - ✅ **1.TRY BLOCK**
#
# - The try block contains code that might raise an exception.
#
# - Python tests this block first.
#
# - If an exception occurs → it jumps immediately to the corresponding except block.
#
# - If no exception occurs → the code runs normally.
#
# **EXAMPLE**:

# %%
try:
    x = 10 / 0   # risky code (ZeroDivisionError)
    print("This will not run")

# %% [markdown]
# ✅ 2. except **BLOCK**:
# - he except block defines how to handle an exception.
#
# - If an exception is raised in the try block, control passes here.
#
# - You can handle specific exceptions or **multiple types of errors**
#
# **EXAMPLE**:

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("You cannot divide by zero!")

# %% [markdown]
# 🔑 **TOGATHER**: try + except:
#
# - try → Attempt to run risky code.
#
# - except → Catch errors and prevent program crash.
#
# **EXAMPLE**:

# %%
try:
    num = int("abc")   # risky conversion
except ValueError:
    print("Invalid input! Please enter a number.")

# %% [markdown]
# **Q15.How does Python's garbage collection system work?**
# - Python uses a combination of reference counting and a cyclic garbage collector to manage memory automatically.
#
# ✅ **1.REFRENCE COUNTING**:
#
# - Every Python object keeps track of how many references (variables, containers, etc.) are pointing to it.
#
# - This count is stored in the object’s **reference counter**.
#
# - When the reference count becomes zero, **the memory is immediately freed**.
#
# **EXAMPLE**:

# %%
import sys

a = [1, 2, 3]
print(sys.getrefcount(a))  # shows reference count

b = a   # new reference
print(sys.getrefcount(a))

del a   # one reference removed
print(sys.getrefcount(b))  # still alive because 'b' points to it

# %% [markdown]
# ✅ **2. PROBLEM WITH  REFRENCE COUNTING → Circular References**
# - Sometimes objects reference each other, creating a cycle.
#
# - EXAMPLE:

# %%
a = []
b = [a]
a.append(b)  # a references b, and b references a

# %% [markdown]
# ✅ **3.CYCLIC GARBAGE COLLECTOR:**
# - To handle circular references, Python has a cyclic garbage collector (part of the gc module).
#
# - It:
#
# - Scans for groups of objects that reference each other but are no longer accessible.
#
# - Breaks these cycles and frees memory.
#
# ✅ **4. GENERATIONAL GARBAGE COLLECTION**:
# - Python divides objects into generations (0, 1, 2).
#
# - New objects start in generation 0.
#
# - If they survive garbage collection, they move to an older generation.
#
# - Objects in older generations are collected less frequently, because they are more likely to be long-lived.
#
# - **Gen 0** → collected most often
#
# - **Gen 2** → collected least often
#
# ✅ **5. MANNUAL CONTROL (optional)**
# - Developers can interact with garbage collection using the gc module.

# %% [markdown]
# **EXAMPLE**:

# %%
import gc

gc.collect()        # forces garbage collection
gc.disable()        # turn off automatic GC (not recommended usually)
gc.enable()         # re-enable it

# %% [markdown]
# **Q16.What is the purpose of the else block in exception handling?**
# - ✅ **PURPOSE**:
# - The else block contains code that should run only if no exceptions occur in the try block.
#
# **STRUCTURE:**

# %%
try:
    # Code that might raise an exception
except SomeException:
    # Code that runs if exception occurs
else:
    # Code that runs ONLY if no exception occurs

# %% [markdown]
# - **KEY POINTS**:
#
# - The else block runs only when the try block succeeds without errors.
#
# - It is often used for code that should execute only when everything goes well inside try.
#
# - It helps keep the try block focused on risky operations (like file I/O, division, etc.), while moving the "safe" follow-up logic into else.
#
#
# **EXAMPLE**:

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ZeroDivisionError:
    print("You can't divide by zero!")
except ValueError:
    print("Invalid input, please enter a number.")
else:
    print("Success! The result is:", result)

# %% [markdown]
# **Q17.What are the common logging levels in Python?**
# - In Python’s built-in logging module, there are five common logging levels, each with a numeric value and a specific purpose:
# | Level        | Numeric Value | Purpose                                                                                                              |
# | ------------ | ------------- | -------------------------------------------------------------------------------------------------------------------- |
# | **DEBUG**    | 10            | Detailed information, useful for diagnosing problems (mostly for developers).                                        |
# | **INFO**     | 20            | General events to confirm that things are working as expected.                                                       |
# | **WARNING**  | 30            | Something unexpected happened, or a situation that might cause a problem in the future, but the program still works. |
# | **ERROR**    | 40            | A serious issue occurred, and part of the program couldn’t run properly.                                             |
# | **CRITICAL** | 50            | A very severe error, the program may not continue running.                                                           |

# %% [markdown]
# **EXAMPLE**:

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

# %% [markdown]
# **Q18.What is the difference between os.fork() and multiprocessing in Python?**
# 1. **os.fork()**
# - **Definition**: A low-level system call (available only on Unix/Linux/macOS, not on Windows).
#
# - **What it does**: Creates a new child process by duplicating the current process.
#
# - The child process is an exact copy of the parent, except for the returned process ID (pid).
#
# - It doesn’t provide built-in tools for process management, communication, or synchronization.
#
# - You need to handle inter-process communication (IPC) manually (using pipes, sockets, etc.).

# %% [markdown]
# **EXAMPLE**:

# %%
import os

pid = os.fork()

if pid == 0:
    print("This is the child process")
else:
    print("This is the parent process, child PID:", pid)

# %% [markdown]
# 2. **Multiprocessing module**:
# - **Definition**: A high-level Python module for process-based parallelism.
#
# - **Cross-platform**: Works on Windows, macOS, and Linux (unlike os.fork()).
#
# - Provides abstractions like **Process, Pool, Queue, and Pipe to make process management easier.**
#
# - Automatically handles **data sharing and synchronization** between processes.
#
# - Safer and more portable than os.fork()

# %% [markdown]
# **EXAMPLE**:

# %%
from multiprocessing import Process

def worker():
    print("Worker process running")

if __name__ == "__main__":
    p = Process(target=worker)
    p.start()
    p.join()

# %% [markdown]
# **KEY DIFFERENCE**:
# | Feature                               | `os.fork()`                              | `multiprocessing`                          |
# | ------------------------------------- | ---------------------------------------- | ------------------------------------------ |
# | **Portability**                       | Only on Unix-like systems                | Cross-platform (Windows, macOS, Linux)     |
# | **Abstraction Level**                 | Low-level (manual handling)              | High-level (convenient API)                |
# | **Process Management**                | Must be handled manually                 | Provides `Process`, `Pool`, `Queue`, etc.  |
# | **IPC (Inter-Process Communication)** | Manual setup (pipes/sockets)             | Built-in support (`Queue`, `Pipe`)         |
# | **Safety**                            | Risky (copy entire process memory space) | Safer and recommended in Python apps       |
# | **Use Case**                          | System-level programming, close to OS    | General-purpose parallelism in Python apps |

# %% [markdown]
# **Q19. What is the importance of closing a file in Python?**
#
# 🔑 **IMPORTANCE OF CLOSING A FILE**:
# - **1.Resource Management**:
# - When you open a file, the operating system allocates resources (like memory buffers and file descriptors).
#
# - If you don’t close it, these resources remain locked and unavailable until the program ends.
#
# - **2.SAVES DATA PROPERLY**
# - When writing to a file, data is often stored in a temporary buffer before being written to disk.
#
# - Closing the file ensures that all buffered data is flushed (actually written to the file). Without closing, some data might never be saved.
#
# - **3.PREVENT FILE CORRUPTION**:
# - If a file isn’t properly closed, it can lead to incomplete writes or corruption, especially in large files.

# %% [markdown]
# - **EXAMPLE**:

# %%
f = open("data.txt", "w")
f.write("Hello, World!")
f.close()   # Ensures "Hello, World!" is actually written to the file

# %% [markdown]
# - ✅ A safer way is to use the **with statement**, which closes the file automatically:

# %%
with open("data.txt", "w") as f:
    f.write("Hello, World!")
# No need to call f.close()

# %% [markdown]
# **Q20.What is the difference between file.read() and file.readline() in Python?**
#
# - **KEY DIFFERENCE**
# - | Method       | What it does                                           | When to use                        |
# | ------------ | ------------------------------------------------------ | ---------------------------------- |
# | `read()`     | Reads the **whole file** (or a chunk if size is given) | When you need all contents at once |
# | `readline()` | Reads **one line at a time**                           | When processing file line by line  |
#
# - **1.Releases System Resources**
# - When you open a file, the operating system allocates resources (like memory and file handles).
#
# - If you don’t close it, these resources remain occupied unnecessarily and can cause resource leaks, especially if many files are opened.
#
# - **2.Saves Data Properly**:
# - When writing to a file, data is often stored in a temporary buffer before being written to disk.
#
# - Closing the file ensures that all buffered data is flushed (actually written to the file). Without closing, some data might never be saved.
#
# - **3.Prevents File Corruption**:
# - If a file isn’t properly closed, it can lead to incomplete writes or corruption, especially in large files.
#
# - **4.Ensures Portability & Good Practice**:
# - Different operating systems handle file access differently. Closing files makes your code more portable and reliable.

# %% [markdown]
# - **EXAMPLE**:

# %%
f = open("data.txt", "w")
f.write("Hello, World!")
f.close()   # Ensures "Hello, World!" is actually written to the file

# %% [markdown]
# **Q21.What is the logging module in Python used for?**
# - The logging module in Python is used to record (or log) messages from your program while it runs. It’s a built-in module that helps track events, errors, warnings, or other information, which is very useful for debugging and monitoring.
#
# - 🔑 **Why use logging instead of print()**
#
# - print() is okay for **quick checks, but logging** is more powerful because:
#
# - It can record messages with different severity levels **(DEBUG, INFO, WARNING, ERROR, CRITICAL).**
#
# - It can save logs to a **file**, not just the console.
#
# - It gives more control (formatting, timestamps, log rotation, etc.)
#
# **EXAMPLE**:

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.DEBUG)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning")
logging.error("This is an error")
logging.critical("This is critical")

# %% [markdown]
# - **COMMON USES OF LOGGING**
#
# - **1.Debugging** – See what your program is doing step by step.
#
# - **2.Error tracking** – Record errors to investigate later.
#
# - **3.Monitoring** – Keep logs of important events in production systems.
#
# - **4.File logging** – Store logs for audit or troubleshooting.
#
#
# **EXAMPLE**:

# %%
logging.basicConfig(filename="app.log", level=logging.INFO,
                    format="%(asctime)s - %(levelname)s - %(message)s")

logging.info("Application started")
logging.warning("Low disk space")
logging.error("File not found")

# %% [markdown]
# **Q22.What is the os module in Python used for in file handling?**
# - The os module in Python provides functions to interact with the operating system, and it is very useful in file handling. It allows you to work with files and directories beyond just opening and reading/writing them.

# %% [markdown]
# **Uses of os module in file handling**
# - **1.WORKING WITH DIRECTORIES (folders)**
# - os.getcwd() → Get current working directory.
#
# - os.chdir(path) → Change current working directory.
#
# - os.listdir(path) → List files and directories in a given path.
#
# - **2.Creating and removing directories**
# - os.mkdir("folder") → Create a new folder.
#
# - os.makedirs("path/to/folder") → Create nested folders.
#
# - os.rmdir("folder") → Remove a folder (if empty).
#
# - os.removedirs("path/to/folder") → Remove nested folders.
#
# - **3.FILE OPERATIONS**
# - os.remove("file.txt") → Delete a file.
#
# - os.rename("old.txt", "new.txt") → Rename a file.
#
# - os.path.exists("file.txt") → Check if a file exists.
#
# - os.path.getsize("file.txt") → Get file size.
#
# **EXAMPLE**:

# %%
import os

# Get current working directory
print("Current directory:", os.getcwd())

# Create a folder
os.mkdir("test_folder")

# Rename it
os.rename("test_folder", "renamed_folder")

# Check if it exists
if os.path.exists("renamed_folder"):
    print("Folder renamed successfully!")

# Remove it
os.rmdir("renamed_folder")

# %% [markdown]
# **Q23.What are the challenges associated with memory management in Python?**
# - 🔑 **CHALLENGES IN PYTHON MEMORY MANAGEMENT**
# - **1.Reference Cycles (Circular References)**
# - If two or more objects reference each other, they create a cycle.
#
# - Example:
#
#       a = []
#       b = [a]
#       a.append(b)   # a → b → a (cycle)
#
# - **2.Memory Leaks**
#
# - Even though Python manages memory, poorly written code (e.g., keeping unnecessary references, global variables, or large caches) can lead to memory not being freed.
#
# - **3.Fragmentation**
#
# - Python’s memory allocator (pymalloc) can cause fragmentation over time, where free memory is scattered in small chunks, making it less efficient for large allocations.
#
# - **4.Objects Not Immediately Freed**
#
# - Python uses reference counting, so an object’s memory is only released when its reference count drops to zero.
#
# - If references are unintentionally kept, memory remains occupied longer than expected.
#
# - **5.Large Data Handling**
#
# - Working with large datasets (e.g., big lists, dictionaries, NumPy arrays) can quickly exhaust available memory.
#
# - Copying large objects instead of referencing them makes this worse.
#
# - **6.Overhead of Objects**
#
# - Every Python object carries extra metadata (like reference count, type info), which makes them more memory-heavy compared to low-level languages like C.
#
# - **7.Global Interpreter Lock (GIL) Issues**
#
# - While not directly a memory leak, the GIL limits true parallelism in threads, which sometimes pushes developers toward multiprocessing
# - Multiprocessing creates separate memory spaces, increasing total memory usage.
#
# - **8.hird-Party Extensions**
#
# - Libraries written in C/C++ (via Cython, ctypes, etc.) may not properly free memory, leading to leaks that Python’s garbage collector cannot handle.

# %% [markdown]
# **Q24. How do you raise an exception manually in Python?**
# - ✅ **KEY POINT**:
#
# - Use raise to trigger exceptions.
#
# - You can raise built-in exceptions (ValueError, TypeError, ZeroDivisionError, etc.) or custom exceptions (user-defined classes inheriting from Exception).
#
# - In Python, you can raise an exception manually using the raise keyword.
#
# **SYNTAX:**
# raise ExceptionType("Error message")

# %% [markdown]
# **Example 1: Raising a built-in exception**:

# %%
# Manually raising a ValueError
x = -5
try:
    if x < 0:
        raise ValueError("Negative values are not allowed!")
except ValueError as e:
    print(f"Caught an error: {e}")
# Out:
# Caught an error: Negative values are not allowed!

# %% [markdown]
# **Example 2: Raising a custom exception**

# %%
# Define a custom exception
class MyError(Exception):
    pass

# Manually raise it and handle it
try:
    raise MyError("This is a custom error!")
except MyError as e:
    print(f"Caught a custom error: {e}")
# Out:
# Caught a custom error: This is a custom error!

# %% [markdown]
# **Q25.Why is it important to use multithreading in certain applications?**
# - ultithreading is important in certain applications because it allows a program to perform multiple tasks concurrently within the same process, improving performance and responsiveness.
#
# - **1.Improved Responsiveness**
# - In applications with a user interface (e.g., GUI apps, games, or web apps), multithreading keeps the interface responsive.
#
# - Example: One thread handles user input while another performs background calculations.
#
# - **Concurrency for I/O-bound tasks**
#
# - Multithreading is especially useful for tasks that spend a lot of time waiting (e.g., reading files, making network requests, database queries).
#
# - Instead of blocking the entire program, threads can run other tasks during the wait time.
#
# - **3.Better Resource Utilization**
#
# - Threads can make better use of CPU idle time, especially when one thread is waiting for I/O operations.
#
# - **4.Parallel Execution (in some cases)**
#
# - While Python has the Global Interpreter Lock (GIL) (which limits true CPU-bound parallelism in threads), threads can still overlap I/O operations.
#
# - In other languages (like Java or C++), multithreading allows true CPU-level parallelism.
#
# - **5.Simplifies Program Structure**
#
# - Instead of writing complex event-driven code, threads let you write straightforward logic where tasks run "in parallel."
#
# - **6.Background Processing**
#
# - Long-running tasks (e.g., downloading files, logging, background monitoring) can run in separate threads without blocking the main thread.

# %% [markdown]
# 🔹 **EXAMPLE: Without vs. With Threads**

# %%
import threading
import time

def task(name):
    print(f"Task {name} started")
    time.sleep(2)
    print(f"Task {name} finished")

# Without threads (sequential)
task(1)
task(2)

# With threads (concurrent)
t1 = threading.Thread(target=task, args=(1,))
t2 = threading.Thread(target=task, args=(2,))
t1.start()
t2.start()
t1.join()
t2.join()
# Out:
# Task 1 started
# Task 1 finished
# Task 2 started
# Task 2 finished
# Task 1 started
# Task 2 started
# Task 1 finished
# Task 2 finished

# %% [markdown]
# # PRACTICAL

# %%
1. # How can you open a file for writing in Python and write a string to it

# %%
# Open a file named 'my_file.txt' in write mode ('w')
# Using a 'with' statement ensures the file is automatically closed
with open('my_file.txt', 'w') as file:
    # Write a string to the file
    file.write("Hello, this is a test string written to the file.")

print("String successfully written to my_file.txt")
# Out:
# String successfully written to my_file.txt

# %%
2.# Write a Python program to read the contents of a file and print each line

try:
    # Open the file in read mode ('r')
    with open('my_file.txt', 'r') as file:
        # Read and print each line
        for line in file:
            print(line, end='') # Use end='' to avoid extra newlines

except FileNotFoundError:
    print("Error: The file 'my_file.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Hello, this is a test string written to the file.

# %%
3.# How would you handle a case where the file doesn't exist while trying to open it for reading?

try:
    # Attempt to open a file that might not exist
    with open('non_existent_file.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    # Handle the case where the file is not found
    print("Error: The file was not found.")
except Exception as e:
    # Handle any other potential exceptions
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file was not found.

# %%
4.# Write a Python script that reads from one file and writes its content to another file?

try:
    # Open the source file in read mode ('r')
    with open('my_file.txt', 'r') as source_file:
        # Read the entire content of the source file
        content = source_file.read()

    # Open the destination file in write mode ('w')
    with open('copied_file.txt', 'w') as destination_file:
        # Write the content to the destination file
        destination_file.write(content)

    print("Content successfully copied from my_file.txt to copied_file.txt")

except FileNotFoundError:
    print("Error: The source file 'my_file.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Content successfully copied from my_file.txt to copied_file.txt

# %%
5.# How would you catch and handle division by zero error in Python?

try:
    # Attempt a division that might result in a ZeroDivisionError
    numerator = 10
    denominator = int(input("Enter a denominator (cannot be zero): "))
    result = numerator / denominator
    print(f"The result of the division is: {result}")
except ZeroDivisionError:
    # Handle the case where division by zero occurs
    print("Error: Cannot divide by zero!")
except ValueError:
    # Also handle cases where the input is not a valid number
    print("Error: Invalid input. Please enter a valid number.")
except Exception as e:
    # Handle any other unexpected errors
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter a denominator (cannot be zero): 10
# The result of the division is: 1.0

# %%
6.# Write a Python program that logs an error message to a log file when a division by zero exception occurs?

# %%
import logging

# Configure logging to write to a file
logging.basicConfig(filename='division_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def divide_numbers(a, b):
    try:
        result = a / b
        print(f"The result of the division is: {result}")
    except ZeroDivisionError:
        # Log an error message if division by zero occurs
        logging.error("Attempted to divide by zero!")
        print("Error: Cannot divide by zero. An error has been logged.")
    except Exception as e:
        # Log any other unexpected errors
        logging.error(f"An unexpected error occurred: {e}")
        print(f"An unexpected error occurred: {e}. An error has been logged.")

# Example usage:
divide_numbers(10, 2)
divide_numbers(10, 0)
divide_numbers(5, 'a') # Example of another error
# Out:
# ERROR:root:Attempted to divide by zero!
# ERROR:root:An unexpected error occurred: unsupported operand type(s) for /: 'int' and 'str'
# The result of the division is: 5.0
# Error: Cannot divide by zero. An error has been logged.
# An unexpected error occurred: unsupported operand type(s) for /: 'int' and 'str'. An error has been logged.

# %%
7. # How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

# Configure logging
# Set the level to DEBUG to see messages from all levels
logging.basicConfig(level=logging.DEBUG)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
8. # Write a program to handle a file opening error using exception handling

try:
    # Attempt to open a file that might not exist or have permission issues
    with open('another_non_existent_file.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    # Handle the case where the file is not found
    print("Error: The file was not found.")
except IOError:
    # Handle other potential I/O errors (like permission issues)
    print("Error: Could not read the file due to an I/O error.")
except Exception as e:
    # Handle any other unexpected exceptions
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file was not found.

# %%
9. # How can you read a file line by line and store its content in a list in Python?

try:
    # Open the file in read mode ('r')
    with open('my_file.txt', 'r') as file:
        # Read all lines into a list
        lines = file.readlines()

    # Print the list of lines
    print("Content of the file as a list:")
    print(lines)

except FileNotFoundError:
    print("Error: The file 'my_file.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Content of the file as a list:
# ['Hello, this is a test string written to the file.']

# %%
10. # How can you append data to an existing file in python?

# %%
# Open the file named 'my_file.txt' in append mode ('a')
with open('my_file.txt', 'a') as file:
    # Append a new line to the file
    file.write("\nThis line is appended to the file.")

print("Data successfully appended to my_file.txt")
# Out:
# Data successfully appended to my_file.txt

# %%
11. # Write a Python program that uses a try-except block to handle an error when attempting to access a
#dictionary key that doesn't exist?

# %%
# Create a sample dictionary
my_dict = {"apple": 1, "banana": 2, "cherry": 3}

try:
    # Attempt to access a key that does not exist
    value = my_dict["grape"]
    print(f"The value is: {value}")
except KeyError:
    # Handle the KeyError
    print("Error: The key 'grape' does not exist in the dictionary.")
except Exception as e:
    # Handle any other unexpected errors
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The key 'grape' does not exist in the dictionary.

# %%
12. # Write a program that demonstrates using multiple except blocks to handle different types of exceptions?

# %%
try:
    # Code that might raise different exceptions
    user_input = input("Enter a number: ")
    num = int(user_input)  # Potential ValueError
    result = 10 / num      # Potential ZeroDivisionError
    print(f"Result: {result}")
except ValueError:
    print("Error: Invalid input. Please enter a valid integer.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter a number: 10
# Result: 1.0

# %%
13. #  How would you check if a file exists before attempting to read it in Python?

# %%
import os

file_path = 'my_file.txt'

if os.path.exists(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print("File content:")
            print(content)
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
else:
    print(f"Error: The file '{file_path}' does not exist.")
# Out:
# File content:
#
# This line is appended to the file.

# %%
14. # Write a program that uses the logging module to log both informational and error messages?

# %%
import logging

# Configure logging to output to the console
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Log an informational message
logging.info("This is an informational message.")

# Log an error message
logging.error("This is an error message.")

# You can also log messages at other levels
logging.warning("This is a warning message.")
logging.debug("This is a debug message (won't show with level=INFO).")
# Out:
# ERROR:root:This is an error message.
# WARNING:root:This is a warning message.

# %%
15. # Write a Python program that prints the content of a file and handles the case when the file is empty?

# %%
try:
    # Specify the file name
    file_name = 'my_file.txt' # You can change this to test with an empty file

    # Open the file in read mode ('r')
    with open(file_name, 'r') as file:
        # Read the entire content of the file
        content = file.read()

        # Check if the content is empty
        if not content:
            print(f"The file '{file_name}' is empty.")
        else:
            print(f"Content of '{file_name}':")
            print(content)

except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Content of 'my_file.txt':
#
# This line is appended to the file.

# %%
16. # Demonstrate how to use memory profiling to check the memory usage of a small program?

# %%
# !pip install memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.12/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from memory_profiler) (5.9.5)

# %%
# %load_ext memory_profiler
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
from memory_profiler import profile

@profile
def create_list():
    my_list = []
    for i in range(1000000):
        my_list.append(i)
    return my_list

if __name__ == '__main__':
    my_large_list = create_list()
    print("List created.")
# Out:
# ERROR: Could not find file /tmp/ipython-input-4229508259.py
# List created.

# %%
17. # Write a Python program to create and write a list of numbers to a file, one number per line?

# %%
# Create a list of numbers
numbers = [10, 25, 5, 40, 15]

# Specify the file name
file_name = 'numbers_list.txt'

try:
    # Open the file in write mode ('w')
    with open(file_name, 'w') as file:
        # Iterate through the list and write each number on a new line
        for number in numbers:
            file.write(str(number) + '\n') # Convert number to string and add newline

    print(f"List of numbers successfully written to '{file_name}'")

except IOError:
    print(f"Error: Could not write to the file '{file_name}'.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# List of numbers successfully written to 'numbers_list.txt'

# %%
18. # How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler

# Create a logger
logger = logging.getLogger("my_logger")
logger.setLevel(logging.DEBUG)  # capture all logs (DEBUG and above)

# Create a rotating file handler
handler = RotatingFileHandler(
    "app.log",       # log file name
    maxBytes=1_000_000,  # rotate after 1 MB
    backupCount=3        # keep last 3 log files as backup
)

# Create a formatter and attach it
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

# Add handler to the logger
logger.addHandler(handler)

# Example logs
for i in range(10000):
    logger.info(f"Log message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:my_logger:Log message number 5000
# INFO:my_logger:Log message number 5001
# INFO:my_logger:Log message number 5002
# INFO:my_logger:Log message number 5003
# INFO:my_logger:Log message number 5004
# INFO:my_logger:Log message number 5005
# INFO:my_logger:Log message number 5006
# INFO:my_logger:Log message number 5007
# INFO:my_logger:Log message number 5008
# INFO:my_logger:Log message number 5009
# INFO:my_logger:Log message number 5010
# INFO:my_logger:Log message number 5011
# INFO:my_logger:Log message number 5012
# INFO:my_logger:Log message number 5013
# INFO:my_logger:Log message number 5014
# INFO:my_logger:Log message number 5015
# INFO:my_logger:Log message number 5016
# INFO:my_logger:Log message number 5017
# INFO:my_logger:Log message number 5018
# INFO:my_logger:Log message number 5019
# INFO:my_logger:Log message number 5020
# INFO:my_logger:Log message number 5021
# INFO:my_logger:Log message number 5022
# INFO:my_logger:Log message number 5023
# INFO:my_logger:Log message number 5024
# INFO:my_logger:Log message number 5025
# INFO:my_logger:Log message number 5026
# INFO:my_logger:Log message number 5027
# INFO:my_logger:Log message number 5028
# INFO:my_logger:Log message number 5029
# INFO:my_logger:Log message number 5030
# INFO:my_logger:Log message number 5031
# INFO:my_logger:Log message number 5032
# INFO:my_logger:Log message number 5033
# INFO:my_logger:Log message number 5034
# INFO:my_logger:Log message number 5035
# INFO:my_logger:Log message number 5036
# INFO:my_logger:Log message number 5037
# INFO:my_logger:Log message number 5038
# INFO:my_logger:Log message number 5039
# INFO:my_logger:Log message number 5040
# INFO:my_logger:Log message number 5041
# INFO:my_logger:Log message number 5042
# INFO:my_logger:Log message number 5043
# INFO:my_logger:Log message number 5044
# INFO:my_logger:Log message number 5045
# INFO:my_logger:Log message number 5046
# INFO:my_logger:Log message number 5047
# INFO:my_logger:Log message number 5048
# INFO:my_logger:Log message number 5049
# INFO:my_logger:Log message number 5050
# INFO:my_logger:Log message number 5051
# INFO:my_logger:Log message number 5052
# INFO:my_logger:Log message number 5053
# INFO:my_logger:Log message number 5054
# INFO:my_logger:Log message number 5055
# INFO:my_logger:Log message number 5056
# INFO:my_logger:Log message number 5057
# INFO:my_logger:Log message number 5058
# INFO:my_logger:Log message number 5059
# INFO:my_logger:Log message number 5060
# INFO:my_logger:Log message number 5061
# INFO:my_logger:Log message number 5062
# INFO:my_logger:Log message number 5063
# INFO:my_logger:Log message number 5064
# INFO:my_logger:Log message number 5065
# INFO:my_logger:Log message number 5066
# INFO:my_logger:Log message number 5067
# INFO:my_logger:Log message number 5068
# INFO:my_logger:Log message number 5069
# INFO:my_logger:Log message number 5070
# INFO:my_logger:Log message number 5071
# INFO:my_logger:Log message number 5072
# INFO:my_logger:Log message number 5073
# INFO:my_logger:Log message number 5074
# INFO:my_logger:Log message number 5075
# INFO:my_logger:Log message number 5076
# INFO:my_logger:Log message number 5077
# INFO:my_logger:Log message number 5078
# INFO:my_logger:Log message number 5079
# INFO:my_logger:Log message number 5080
# INFO:my_logger:Log message number 5081
# INFO:my_logger:Log message number 5082
# INFO:my_logger:Log message number 5083
# INFO:my_logger:Log message number 5084
# INFO:my_logger:Log message number 5085
# INFO:my_logger:Log message number 5086
# INFO:my_logger:Log message number 5087
# INFO:my_logger:Log message number 5088
# INFO:my_logger:Log message number 5089
# INFO:my_logger:Log message number 5090
# INFO:my_logger:Log message number 5091
# INFO:my_logger:Log message number 5092
# INFO:my_logger:Log message number 5093
# INFO:my_logger:Log message number 5094
# INFO:my_logger:Log message number 5095
# INFO:my_logger:Log message number 5096
# INFO:my_logger:Log message number 5097
# INFO:my_logger:Log message number 5098
# INFO:my_logger:Log message number 5099
# INFO:my_logger:Log message number 5100
# INFO:my_logger:Log message number 5101
# INFO:my_logger:Log message number 5102
# INFO:my_logger:Log message number 5103
# INFO:my_logger:Log message number 5104
# INFO:my_logger:Log message number 5105
# INFO:my_logger:Log message number 5106
# INFO:my_logger:Log message number 5107
# INFO:my_logger:Log message number 5108
# INFO:my_logger:Log message number 5109
# INFO:my_logger:Log message number 5110
# INFO:my_logger:Log message number 5111
# INFO:my_logger:Log message number 5112
# INFO:my_logger:Log message number 5113
# INFO:my_logger:Log message number 5114
# INFO:my_logger:Log message number 5115
# INFO:my_logger:Log message number 5116
# INFO:my_logger:Log message number 5117
# INFO:my_logger:Log message number 5118
# INFO:my_logger:Log message number 5119
# INFO:my_logger:Log message number 5120
# INFO:my_logger:Log message number 5121
# INFO:my_logger:Log message number 5122
# INFO:my_logger:Log message number 5123
# INFO:my_logger:Log message number 5124
# INFO:my_logger:Log message number 5125
# INFO:my_logger:Log message number 5126
# INFO:my_logger:Log message number 5127
# INFO:my_logger:Log message number 5128
# INFO:my_logger:Log message number 5129
# INFO:my_logger:Log message number 5130
# INFO:my_logger:Log message number 5131
# INFO:my_logger:Log message number 5132
# INFO:my_logger:Log message number 5133
# INFO:my_logger:Log message number 5134
# INFO:my_logger:Log message number 5135
# INFO:my_logger:Log message number 5136
# INFO:my_logger:Log message number 5137
# INFO:my_logger:Log message number 5138
# INFO:my_logger:Log message number 5139
# INFO:my_logger:Log message number 5140
# INFO:my_logger:Log message number 5141
# INFO:my_logger:Log message number 5142
# INFO:my_logger:Log message number 5143
# INFO:my_logger:Log message number 5144
# INFO:my_logger:Log message number 5145
# INFO:my_logger:Log message number 5146
# INFO:my_logger:Log message number 5147
# INFO:my_logger:Log message number 5148
# INFO:my_logger:Log message number 5149
# INFO:my_logger:Log message number 5150
# INFO:my_logger:Log message number 5151
# INFO:my_logger:Log message number 5152
# INFO:my_logger:Log message number 5153
# INFO:my_logger:Log message number 5154
# INFO:my_logger:Log message number 5155
# INFO:my_logger:Log message number 5156
# INFO:my_logger:Log message number 5157
# INFO:my_logger:Log message number 5158
# INFO:my_logger:Log message number 5159
# INFO:my_logger:Log message number 5160
# INFO:my_logger:Log message number 5161
# INFO:my_logger:Log message number 5162
# INFO:my_logger:Log message number 5163
# INFO:my_logger:Log message number 5164
# INFO:my_logger:Log message number 5165
# INFO:my_logger:Log message number 5166
# INFO:my_logger:Log message number 5167
# INFO:my_logger:Log message number 5168
# INFO:my_logger:Log message number 5169
# INFO:my_logger:Log message number 5170
# INFO:my_logger:Log message number 5171
# INFO:my_logger:Log message number 5172
# INFO:my_logger:Log message number 5173
# INFO:my_logger:Log message number 5174
# INFO:my_logger:Log message number 5175
# INFO:my_logger:Log message number 5176
# INFO:my_logger:Log message number 5177
# INFO:my_logger:Log message number 5178
# INFO:my_logger:Log message number 5179
# INFO:my_logger:Log message number 5180
# INFO:my_logger:Log message number 5181
# INFO:my_logger:Log message number 5182
# INFO:my_logger:Log message number 5183
# INFO:my_logger:Log message number 5184
# INFO:my_logger:Log message number 5185
# INFO:my_logger:Log message number 5186
# INFO:my_logger:Log message number 5187
# INFO:my_logger:Log message number 5188
# INFO:my_logger:Log message number 5189
# INFO:my_logger:Log message number 5190
# INFO:my_logger:Log message number 5191
# INFO:my_logger:Log message number 5192
# INFO:my_logger:Log message number 5193
# INFO:my_logger:Log message number 5194
# INFO:my_logger:Log message number 5195
# INFO:my_logger:Log message number 5196
# INFO:my_logger:Log message number 5197
# INFO:my_logger:Log message number 5198
# INFO:my_logger:Log message number 5199
# INFO:my_logger:Log message number 5200
# INFO:my_logger:Log message number 5201
# INFO:my_logger:Log message number 5202
# INFO:my_logger:Log message number 5203
# INFO:my_logger:Log message number 5204
# INFO:my_logger:Log message number 5205
# INFO:my_logger:Log message number 5206
# INFO:my_logger:Log message number 5207
# INFO:my_logger:Log message number 5208
# INFO:my_logger:Log message number 5209
# INFO:my_logger:Log message number 5210
# INFO:my_logger:Log message number 5211
# INFO:my_logger:Log message number 5212
# INFO:my_logger:Log message number 5213
# INFO:my_logger:Log message number 5214
# INFO:my_logger:Log message number 5215
# INFO:my_logger:Log message number 5216
# INFO:my_logger:Log message number 5217
# INFO:my_logger:Log message number 5218
# INFO:my_logger:Log message number 5219
# INFO:my_logger:Log message number 5220
# INFO:my_logger:Log message number 5221
# INFO:my_logger:Log message number 5222
# INFO:my_logger:Log message number 5223
# INFO:my_logger:Log message number 5224
# INFO:my_logger:Log message number 5225
# INFO:my_logger:Log message number 5226
# INFO:my_logger:Log message number 5227
# INFO:my_logger:Log message number 5228
# INFO:my_logger:Log message number 5229
# INFO:my_logger:Log message number 5230
# INFO:my_logger:Log message number 5231
# INFO:my_logger:Log message number 5232
# INFO:my_logger:Log message number 5233
# INFO:my_logger:Log message number 5234
# INFO:my_logger:Log message number 5235
# INFO:my_logger:Log message number 5236
# INFO:my_logger:Log message number 5237
# INFO:my_logger:Log message number 5238
# INFO:my_logger:Log message number 5239
# INFO:my_logger:Log message number 5240
# INFO:my_logger:Log message number 5241
# INFO:my_logger:Log message number 5242
# INFO:my_logger:Log message number 5243
# INFO:my_logger:Log message number 5244
# INFO:my_logger:Log message number 5245
# INFO:my_logger:Log message number 5246
# INFO:my_logger:Log message number 5247
# INFO:my_logger:Log message number 5248
# INFO:my_logger:Log message number 5249
# INFO:my_logger:Log message number 5250
# INFO:my_logger:Log message number 5251
# INFO:my_logger:Log message number 5252
# INFO:my_logger:Log message number 5253
# INFO:my_logger:Log message number 5254
# INFO:my_logger:Log message number 5255
# INFO:my_logger:Log message number 5256
# INFO:my_logger:Log message number 5257
# INFO:my_logger:Log message number 5258
# INFO:my_logger:Log message number 5259
# INFO:my_logger:Log message number 5260
# INFO:my_logger:Log message number 5261
# INFO:my_logger:Log message number 5262
# INFO:my_logger:Log message number 5263
# INFO:my_logger:Log message number 5264
# INFO:my_logger:Log message number 5265
# INFO:my_logger:Log message number 5266
# INFO:my_logger:Log message number 5267
# INFO:my_logger:Log message number 5268
# INFO:my_logger:Log message number 5269
# INFO:my_logger:Log message number 5270
# INFO:my_logger:Log message number 5271
# INFO:my_logger:Log message number 5272
# INFO:my_logger:Log message number 5273
# INFO:my_logger:Log message number 5274
# INFO:my_logger:Log message number 5275
# INFO:my_logger:Log message number 5276
# INFO:my_logger:Log message number 5277
# INFO:my_logger:Log message number 5278
# INFO:my_logger:Log message number 5279
# INFO:my_logger:Log message number 5280
# INFO:my_logger:Log message number 5281
# INFO:my_logger:Log message number 5282
# INFO:my_logger:Log message number 5283
# INFO:my_logger:Log message number 5284
# INFO:my_logger:Log message number 5285
# INFO:my_logger:Log message number 5286
# INFO:my_logger:Log message number 5287
# INFO:my_logger:Log message number 5288
# INFO:my_logger:Log message number 5289
# INFO:my_logger:Log message number 5290
# INFO:my_logger:Log message number 5291
# INFO:my_logger:Log message number 5292
# INFO:my_logger:Log message number 5293
# INFO:my_logger:Log message number 5294
# INFO:my_logger:Log message number 5295
# INFO:my_logger:Log message number 5296
# INFO:my_logger:Log message number 5297
# INFO:my_logger:Log message number 5298
# INFO:my_logger:Log message number 5299
# INFO:my_logger:Log message number 5300
# INFO:my_logger:Log message number 5301
# INFO:my_logger:Log message number 5302
# INFO:my_logger:Log message number 5303
# INFO:my_logger:Log message number 5304
# INFO:my_logger:Log message number 5305
# INFO:my_logger:Log message number 5306
# INFO:my_logger:Log message number 5307
# INFO:my_logger:Log message number 5308
# INFO:my_logger:Log message number 5309
# INFO:my_logger:Log message number 5310
# INFO:my_logger:Log message number 5311
# INFO:my_logger:Log message number 5312
# INFO:my_logger:Log message number 5313
# INFO:my_logger:Log message number 5314
# INFO:my_logger:Log message number 5315
# INFO:my_logger:Log message number 5316
# INFO:my_logger:Log message number 5317
# INFO:my_logger:Log message number 5318
# INFO:my_logger:Log message number 5319
# INFO:my_logger:Log message number 5320
# INFO:my_logger:Log message number 5321
# INFO:my_logger:Log message number 5322
# INFO:my_logger:Log message number 5323
# INFO:my_logger:Log message number 5324
# INFO:my_logger:Log message number 5325
# INFO:my_logger:Log message number 5326
# INFO:my_logger:Log message number 5327
# INFO:my_logger:Log message number 5328
# INFO:my_logger:Log message number 5329
# INFO:my_logger:Log message number 5330
# INFO:my_logger:Log message number 5331
# INFO:my_logger:Log message number 5332
# INFO:my_logger:Log message number 5333
# INFO:my_logger:Log message number 5334
# INFO:my_logger:Log message number 5335
# INFO:my_logger:Log message number 5336
# INFO:my_logger:Log message number 5337
# INFO:my_logger:Log message number 5338
# INFO:my_logger:Log message number 5339
# INFO:my_logger:Log message number 5340
# INFO:my_logger:Log message number 5341
# INFO:my_logger:Log message number 5342
# INFO:my_logger:Log message number 5343
# INFO:my_logger:Log message number 5344
# INFO:my_logger:Log message number 5345
# INFO:my_logger:Log message number 5346
# INFO:my_logger:Log message number 5347
# INFO:my_logger:Log message number 5348
# INFO:my_logger:Log message number 5349
# INFO:my_logger:Log message number 5350
# INFO:my_logger:Log message number 5351
# INFO:my_logger:Log message number 5352
# INFO:my_logger:Log message number 5353
# INFO:my_logger:Log message number 5354
# INFO:my_logger:Log message number 5355
# INFO:my_logger:Log message number 5356
# INFO:my_logger:Log message number 5357
# INFO:my_logger:Log message number 5358
# INFO:my_logger:Log message number 5359
# INFO:my_logger:Log message number 5360
# INFO:my_logger:Log message number 5361
# INFO:my_logger:Log message number 5362
# INFO:my_logger:Log message number 5363
# INFO:my_logger:Log message number 5364
# INFO:my_logger:Log message number 5365
# INFO:my_logger:Log message number 5366
# INFO:my_logger:Log message number 5367
# INFO:my_logger:Log message number 5368
# INFO:my_logger:Log message number 5369
# INFO:my_logger:Log message number 5370
# INFO:my_logger:Log message number 5371
# INFO:my_logger:Log message number 5372
# INFO:my_logger:Log message number 5373
# INFO:my_logger:Log message number 5374
# INFO:my_logger:Log message number 5375
# INFO:my_logger:Log message number 5376
# INFO:my_logger:Log message number 5377
# INFO:my_logger:Log message number 5378
# INFO:my_logger:Log message number 5379
# INFO:my_logger:Log message number 5380
# INFO:my_logger:Log message number 5381
# INFO:my_logger:Log message number 5382
# INFO:my_logger:Log message number 5383
# INFO:my_logger:Log message number 5384
# INFO:my_logger:Log message number 5385
# INFO:my_logger:Log message number 5386
# INFO:my_logger:Log message number 5387
# INFO:my_logger:Log message number 5388
# INFO:my_logger:Log message number 5389
# INFO:my_logger:Log message number 5390
# INFO:my_logger:Log message number 5391
# INFO:my_logger:Log message number 5392
# INFO:my_logger:Log message number 5393
# INFO:my_logger:Log message number 5394
# INFO:my_logger:Log message number 5395
# INFO:my_logger:Log message number 5396
# INFO:my_logger:Log message number 5397
# INFO:my_logger:Log message number 5398
# INFO:my_logger:Log message number 5399
# INFO:my_logger:Log message number 5400
# INFO:my_logger:Log message number 5401
# INFO:my_logger:Log message number 5402
# INFO:my_logger:Log message number 5403
# INFO:my_logger:Log message number 5404
# INFO:my_logger:Log message number 5405
# INFO:my_logger:Log message number 5406
# INFO:my_logger:Log message number 5407
# INFO:my_logger:Log message number 5408
# INFO:my_logger:Log message number 5409
# INFO:my_logger:Log message number 5410
# INFO:my_logger:Log message number 5411
# INFO:my_logger:Log message number 5412
# INFO:my_logger:Log message number 5413
# INFO:my_logger:Log message number 5414
# INFO:my_logger:Log message number 5415
# INFO:my_logger:Log message number 5416
# INFO:my_logger:Log message number 5417
# INFO:my_logger:Log message number 5418
# INFO:my_logger:Log message number 5419
# INFO:my_logger:Log message number 5420
# INFO:my_logger:Log message number 5421
# INFO:my_logger:Log message number 5422
# INFO:my_logger:Log message number 5423
# INFO:my_logger:Log message number 5424
# INFO:my_logger:Log message number 5425
# INFO:my_logger:Log message number 5426
# INFO:my_logger:Log message number 5427
# INFO:my_logger:Log message number 5428
# INFO:my_logger:Log message number 5429
# INFO:my_logger:Log message number 5430
# INFO:my_logger:Log message number 5431
# INFO:my_logger:Log message number 5432
# INFO:my_logger:Log message number 5433
# INFO:my_logger:Log message number 5434
# INFO:my_logger:Log message number 5435
# INFO:my_logger:Log message number 5436
# INFO:my_logger:Log message number 5437
# INFO:my_logger:Log message number 5438
# INFO:my_logger:Log message number 5439
# INFO:my_logger:Log message number 5440
# INFO:my_logger:Log message number 5441
# INFO:my_logger:Log message number 5442
# INFO:my_logger:Log message number 5443
# INFO:my_logger:Log message number 5444
# INFO:my_logger:Log message number 5445
# INFO:my_logger:Log message number 5446
# INFO:my_logger:Log message number 5447
# INFO:my_logger:Log message number 5448
# INFO:my_logger:Log message number 5449
# INFO:my_logger:Log message number 5450
# INFO:my_logger:Log message number 5451
# INFO:my_logger:Log message number 5452
# INFO:my_logger:Log message number 5453
# INFO:my_logger:Log message number 5454
# INFO:my_logger:Log message number 5455
# INFO:my_logger:Log message number 5456
# INFO:my_logger:Log message number 5457
# INFO:my_logger:Log message number 5458
# INFO:my_logger:Log message number 5459
# INFO:my_logger:Log message number 5460
# INFO:my_logger:Log message number 5461
# INFO:my_logger:Log message number 5462
# INFO:my_logger:Log message number 5463
# INFO:my_logger:Log message number 5464
# INFO:my_logger:Log message number 5465
# INFO:my_logger:Log message number 5466
# INFO:my_logger:Log message number 5467
# INFO:my_logger:Log message number 5468
# INFO:my_logger:Log message number 5469
# INFO:my_logger:Log message number 5470
# INFO:my_logger:Log message number 5471
# INFO:my_logger:Log message number 5472
# INFO:my_logger:Log message number 5473
# INFO:my_logger:Log message number 5474
# INFO:my_logger:Log message number 5475
# INFO:my_logger:Log message number 5476
# INFO:my_logger:Log message number 5477
# INFO:my_logger:Log message number 5478
# INFO:my_logger:Log message number 5479
# INFO:my_logger:Log message number 5480
# INFO:my_logger:Log message number 5481
# INFO:my_logger:Log message number 5482
# INFO:my_logger:Log message number 5483
# INFO:my_logger:Log message number 5484
# INFO:my_logger:Log message number 5485
# INFO:my_logger:Log message number 5486
# INFO:my_logger:Log message number 5487
# INFO:my_logger:Log message number 5488
# INFO:my_logger:Log message number 5489
# INFO:my_logger:Log message number 5490
# INFO:my_logger:Log message number 5491
# INFO:my_logger:Log message number 5492
# INFO:my_logger:Log message number 5493
# INFO:my_logger:Log message number 5494
# INFO:my_logger:Log message number 5495
# INFO:my_logger:Log message number 5496
# INFO:my_logger:Log message number 5497
# INFO:my_logger:Log message number 5498
# INFO:my_logger:Log message number 5499
# INFO:my_logger:Log message number 5500
# INFO:my_logger:Log message number 5501
# INFO:my_logger:Log message number 5502
# INFO:my_logger:Log message number 5503
# INFO:my_logger:Log message number 5504
# INFO:my_logger:Log message number 5505
# INFO:my_logger:Log message number 5506
# INFO:my_logger:Log message number 5507
# INFO:my_logger:Log message number 5508
# INFO:my_logger:Log message number 5509
# INFO:my_logger:Log message number 5510
# INFO:my_logger:Log message number 5511
# INFO:my_logger:Log message number 5512
# INFO:my_logger:Log message number 5513
# INFO:my_logger:Log message number 5514
# INFO:my_logger:Log message number 5515
# INFO:my_logger:Log message number 5516
# INFO:my_logger:Log message number 5517
# INFO:my_logger:Log message number 5518
# INFO:my_logger:Log message number 5519
# INFO:my_logger:Log message number 5520
# INFO:my_logger:Log message number 5521
# INFO:my_logger:Log message number 5522
# INFO:my_logger:Log message number 5523
# INFO:my_logger:Log message number 5524
# INFO:my_logger:Log message number 5525
# INFO:my_logger:Log message number 5526
# INFO:my_logger:Log message number 5527
# INFO:my_logger:Log message number 5528
# INFO:my_logger:Log message number 5529
# INFO:my_logger:Log message number 5530
# INFO:my_logger:Log message number 5531
# INFO:my_logger:Log message number 5532
# INFO:my_logger:Log message number 5533
# INFO:my_logger:Log message number 5534
# INFO:my_logger:Log message number 5535
# INFO:my_logger:Log message number 5536
# INFO:my_logger:Log message number 5537
# INFO:my_logger:Log message number 5538
# INFO:my_logger:Log message number 5539
# INFO:my_logger:Log message number 5540
# INFO:my_logger:Log message number 5541
# INFO:my_logger:Log message number 5542
# INFO:my_logger:Log message number 5543
# INFO:my_logger:Log message number 5544
# INFO:my_logger:Log message number 5545
# INFO:my_logger:Log message number 5546
# INFO:my_logger:Log message number 5547
# INFO:my_logger:Log message number 5548
# INFO:my_logger:Log message number 5549
# INFO:my_logger:Log message number 5550
# INFO:my_logger:Log message number 5551
# INFO:my_logger:Log message number 5552
# INFO:my_logger:Log message number 5553
# INFO:my_logger:Log message number 5554
# INFO:my_logger:Log message number 5555
# INFO:my_logger:Log message number 5556
# INFO:my_logger:Log message number 5557
# INFO:my_logger:Log message number 5558
# INFO:my_logger:Log message number 5559
# INFO:my_logger:Log message number 5560
# INFO:my_logger:Log message number 5561
# INFO:my_logger:Log message number 5562
# INFO:my_logger:Log message number 5563
# INFO:my_logger:Log message number 5564
# INFO:my_logger:Log message number 5565
# INFO:my_logger:Log message number 5566
# INFO:my_logger:Log message number 5567
# INFO:my_logger:Log message number 5568
# INFO:my_logger:Log message number 5569
# INFO:my_logger:Log message number 5570
# INFO:my_logger:Log message number 5571
# INFO:my_logger:Log message number 5572
# INFO:my_logger:Log message number 5573
# INFO:my_logger:Log message number 5574
# INFO:my_logger:Log message number 5575
# INFO:my_logger:Log message number 5576
# INFO:my_logger:Log message number 5577
# INFO:my_logger:Log message number 5578
# INFO:my_logger:Log message number 5579
# INFO:my_logger:Log message number 5580
# INFO:my_logger:Log message number 5581
# INFO:my_logger:Log message number 5582
# INFO:my_logger:Log message number 5583
# INFO:my_logger:Log message number 5584
# INFO:my_logger:Log message number 5585
# INFO:my_logger:Log message number 5586
# INFO:my_logger:Log message number 5587
# INFO:my_logger:Log message number 5588
# INFO:my_logger:Log message number 5589
# INFO:my_logger:Log message number 5590
# INFO:my_logger:Log message number 5591
# INFO:my_logger:Log message number 5592
# INFO:my_logger:Log message number 5593
# INFO:my_logger:Log message number 5594
# INFO:my_logger:Log message number 5595
# INFO:my_logger:Log message number 5596
# INFO:my_logger:Log message number 5597
# INFO:my_logger:Log message number 5598
# INFO:my_logger:Log message number 5599
# INFO:my_logger:Log message number 5600
# INFO:my_logger:Log message number 5601
# INFO:my_logger:Log message number 5602
# INFO:my_logger:Log message number 5603
# INFO:my_logger:Log message number 5604
# INFO:my_logger:Log message number 5605
# INFO:my_logger:Log message number 5606
# INFO:my_logger:Log message number 5607
# INFO:my_logger:Log message number 5608
# INFO:my_logger:Log message number 5609
# INFO:my_logger:Log message number 5610
# INFO:my_logger:Log message number 5611
# INFO:my_logger:Log message number 5612
# INFO:my_logger:Log message number 5613
# INFO:my_logger:Log message number 5614
# INFO:my_logger:Log message number 5615
# INFO:my_logger:Log message number 5616
# INFO:my_logger:Log message number 5617
# INFO:my_logger:Log message number 5618
# INFO:my_logger:Log message number 5619
# INFO:my_logger:Log message number 5620
# INFO:my_logger:Log message number 5621
# INFO:my_logger:Log message number 5622
# INFO:my_logger:Log message number 5623
# INFO:my_logger:Log message number 5624
# INFO:my_logger:Log message number 5625
# INFO:my_logger:Log message number 5626
# INFO:my_logger:Log message number 5627
# INFO:my_logger:Log message number 5628
# INFO:my_logger:Log message number 5629
# INFO:my_logger:Log message number 5630
# INFO:my_logger:Log message number 5631
# INFO:my_logger:Log message number 5632
# INFO:my_logger:Log message number 5633
# INFO:my_logger:Log message number 5634
# INFO:my_logger:Log message number 5635
# INFO:my_logger:Log message number 5636
# INFO:my_logger:Log message number 5637
# INFO:my_logger:Log message number 5638
# INFO:my_logger:Log message number 5639
# INFO:my_logger:Log message number 5640
# INFO:my_logger:Log message number 5641
# INFO:my_logger:Log message number 5642
# INFO:my_logger:Log message number 5643
# INFO:my_logger:Log message number 5644
# INFO:my_logger:Log message number 5645
# INFO:my_logger:Log message number 5646
# INFO:my_logger:Log message number 5647
# INFO:my_logger:Log message number 5648
# INFO:my_logger:Log message number 5649
# INFO:my_logger:Log message number 5650
# INFO:my_logger:Log message number 5651
# INFO:my_logger:Log message number 5652
# INFO:my_logger:Log message number 5653
# INFO:my_logger:Log message number 5654
# INFO:my_logger:Log message number 5655
# INFO:my_logger:Log message number 5656
# INFO:my_logger:Log message number 5657
# INFO:my_logger:Log message number 5658
# INFO:my_logger:Log message number 5659
# INFO:my_logger:Log message number 5660
# INFO:my_logger:Log message number 5661
# INFO:my_logger:Log message number 5662
# INFO:my_logger:Log message number 5663
# INFO:my_logger:Log message number 5664
# INFO:my_logger:Log message number 5665
# INFO:my_logger:Log message number 5666
# INFO:my_logger:Log message number 5667
# INFO:my_logger:Log message number 5668
# INFO:my_logger:Log message number 5669
# INFO:my_logger:Log message number 5670
# INFO:my_logger:Log message number 5671
# INFO:my_logger:Log message number 5672
# INFO:my_logger:Log message number 5673
# INFO:my_logger:Log message number 5674
# INFO:my_logger:Log message number 5675
# INFO:my_logger:Log message number 5676
# INFO:my_logger:Log message number 5677
# INFO:my_logger:Log message number 5678
# INFO:my_logger:Log message number 5679
# INFO:my_logger:Log message number 5680
# INFO:my_logger:Log message number 5681
# INFO:my_logger:Log message number 5682
# INFO:my_logger:Log message number 5683
# INFO:my_logger:Log message number 5684
# INFO:my_logger:Log message number 5685
# INFO:my_logger:Log message number 5686
# INFO:my_logger:Log message number 5687
# INFO:my_logger:Log message number 5688
# INFO:my_logger:Log message number 5689
# INFO:my_logger:Log message number 5690
# INFO:my_logger:Log message number 5691
# INFO:my_logger:Log message number 5692
# INFO:my_logger:Log message number 5693
# INFO:my_logger:Log message number 5694
# INFO:my_logger:Log message number 5695
# INFO:my_logger:Log message number 5696
# INFO:my_logger:Log message number 5697
# INFO:my_logger:Log message number 5698
# INFO:my_logger:Log message number 5699
# INFO:my_logger:Log message number 5700
# INFO:my_logger:Log message number 5701
# INFO:my_logger:Log message number 5702
# INFO:my_logger:Log message number 5703
# INFO:my_logger:Log message number 5704
# INFO:my_logger:Log message number 5705
# INFO:my_logger:Log message number 5706
# INFO:my_logger:Log message number 5707
# INFO:my_logger:Log message number 5708
# INFO:my_logger:Log message number 5709
# INFO:my_logger:Log message number 5710
# INFO:my_logger:Log message number 5711
# INFO:my_logger:Log message number 5712
# INFO:my_logger:Log message number 5713
# INFO:my_logger:Log message number 5714
# INFO:my_logger:Log message number 5715
# INFO:my_logger:Log message number 5716
# INFO:my_logger:Log message number 5717
# INFO:my_logger:Log message number 5718
# INFO:my_logger:Log message number 5719
# INFO:my_logger:Log message number 5720
# INFO:my_logger:Log message number 5721
# INFO:my_logger:Log message number 5722
# INFO:my_logger:Log message number 5723
# INFO:my_logger:Log message number 5724
# INFO:my_logger:Log message number 5725
# INFO:my_logger:Log message number 5726
# INFO:my_logger:Log message number 5727
# INFO:my_logger:Log message number 5728
# INFO:my_logger:Log message number 5729
# INFO:my_logger:Log message number 5730
# INFO:my_logger:Log message number 5731
# INFO:my_logger:Log message number 5732
# INFO:my_logger:Log message number 5733
# INFO:my_logger:Log message number 5734
# INFO:my_logger:Log message number 5735
# INFO:my_logger:Log message number 5736
# INFO:my_logger:Log message number 5737
# INFO:my_logger:Log message number 5738
# INFO:my_logger:Log message number 5739
# INFO:my_logger:Log message number 5740
# INFO:my_logger:Log message number 5741
# INFO:my_logger:Log message number 5742
# INFO:my_logger:Log message number 5743
# INFO:my_logger:Log message number 5744
# INFO:my_logger:Log message number 5745
# INFO:my_logger:Log message number 5746
# INFO:my_logger:Log message number 5747
# INFO:my_logger:Log message number 5748
# INFO:my_logger:Log message number 5749
# INFO:my_logger:Log message number 5750
# INFO:my_logger:Log message number 5751
# INFO:my_logger:Log message number 5752
# INFO:my_logger:Log message number 5753
# INFO:my_logger:Log message number 5754
# INFO:my_logger:Log message number 5755
# INFO:my_logger:Log message number 5756
# INFO:my_logger:Log message number 5757
# INFO:my_logger:Log message number 5758
# INFO:my_logger:Log message number 5759
# INFO:my_logger:Log message number 5760
# INFO:my_logger:Log message number 5761
# INFO:my_logger:Log message number 5762
# INFO:my_logger:Log message number 5763
# INFO:my_logger:Log message number 5764
# INFO:my_logger:Log message number 5765
# INFO:my_logger:Log message number 5766
# INFO:my_logger:Log message number 5767
# INFO:my_logger:Log message number 5768
# INFO:my_logger:Log message number 5769
# INFO:my_logger:Log message number 5770
# INFO:my_logger:Log message number 5771
# INFO:my_logger:Log message number 5772
# INFO:my_logger:Log message number 5773
# INFO:my_logger:Log message number 5774
# INFO:my_logger:Log message number 5775
# INFO:my_logger:Log message number 5776
# INFO:my_logger:Log message number 5777
# INFO:my_logger:Log message number 5778
# INFO:my_logger:Log message number 5779
# INFO:my_logger:Log message number 5780
# INFO:my_logger:Log message number 5781
# INFO:my_logger:Log message number 5782
# INFO:my_logger:Log message number 5783
# INFO:my_logger:Log message number 5784
# INFO:my_logger:Log message number 5785
# INFO:my_logger:Log message number 5786
# INFO:my_logger:Log message number 5787
# INFO:my_logger:Log message number 5788
# INFO:my_logger:Log message number 5789
# INFO:my_logger:Log message number 5790
# INFO:my_logger:Log message number 5791
# INFO:my_logger:Log message number 5792
# INFO:my_logger:Log message number 5793
# INFO:my_logger:Log message number 5794
# INFO:my_logger:Log message number 5795
# INFO:my_logger:Log message number 5796
# INFO:my_logger:Log message number 5797
# INFO:my_logger:Log message number 5798
# INFO:my_logger:Log message number 5799
# INFO:my_logger:Log message number 5800
# INFO:my_logger:Log message number 5801
# INFO:my_logger:Log message number 5802
# INFO:my_logger:Log message number 5803
# INFO:my_logger:Log message number 5804
# INFO:my_logger:Log message number 5805
# INFO:my_logger:Log message number 5806
# INFO:my_logger:Log message number 5807
# INFO:my_logger:Log message number 5808
# INFO:my_logger:Log message number 5809
# INFO:my_logger:Log message number 5810
# INFO:my_logger:Log message number 5811
# INFO:my_logger:Log message number 5812
# INFO:my_logger:Log message number 5813
# INFO:my_logger:Log message number 5814
# INFO:my_logger:Log message number 5815
# INFO:my_logger:Log message number 5816
# INFO:my_logger:Log message number 5817
# INFO:my_logger:Log message number 5818
# INFO:my_logger:Log message number 5819
# INFO:my_logger:Log message number 5820
# INFO:my_logger:Log message number 5821
# INFO:my_logger:Log message number 5822
# INFO:my_logger:Log message number 5823
# INFO:my_logger:Log message number 5824
# INFO:my_logger:Log message number 5825
# INFO:my_logger:Log message number 5826
# INFO:my_logger:Log message number 5827
# INFO:my_logger:Log message number 5828
# INFO:my_logger:Log message number 5829
# INFO:my_logger:Log message number 5830
# INFO:my_logger:Log message number 5831
# INFO:my_logger:Log message number 5832
# INFO:my_logger:Log message number 5833
# INFO:my_logger:Log message number 5834
# INFO:my_logger:Log message number 5835
# INFO:my_logger:Log message number 5836
# INFO:my_logger:Log message number 5837
# INFO:my_logger:Log message number 5838
# INFO:my_logger:Log message number 5839
# INFO:my_logger:Log message number 5840
# INFO:my_logger:Log message number 5841
# INFO:my_logger:Log message number 5842
# INFO:my_logger:Log message number 5843
# INFO:my_logger:Log message number 5844
# INFO:my_logger:Log message number 5845
# INFO:my_logger:Log message number 5846
# INFO:my_logger:Log message number 5847
# INFO:my_logger:Log message number 5848
# INFO:my_logger:Log message number 5849
# INFO:my_logger:Log message number 5850
# INFO:my_logger:Log message number 5851
# INFO:my_logger:Log message number 5852
# INFO:my_logger:Log message number 5853
# INFO:my_logger:Log message number 5854
# INFO:my_logger:Log message number 5855
# INFO:my_logger:Log message number 5856
# INFO:my_logger:Log message number 5857
# INFO:my_logger:Log message number 5858
# INFO:my_logger:Log message number 5859
# INFO:my_logger:Log message number 5860
# INFO:my_logger:Log message number 5861
# INFO:my_logger:Log message number 5862
# INFO:my_logger:Log message number 5863
# INFO:my_logger:Log message number 5864
# INFO:my_logger:Log message number 5865
# INFO:my_logger:Log message number 5866
# INFO:my_logger:Log message number 5867
# INFO:my_logger:Log message number 5868
# INFO:my_logger:Log message number 5869
# INFO:my_logger:Log message number 5870
# INFO:my_logger:Log message number 5871
# INFO:my_logger:Log message number 5872
# INFO:my_logger:Log message number 5873
# INFO:my_logger:Log message number 5874
# INFO:my_logger:Log message number 5875
# INFO:my_logger:Log message number 5876
# INFO:my_logger:Log message number 5877
# INFO:my_logger:Log message number 5878
# INFO:my_logger:Log message number 5879
# INFO:my_logger:Log message number 5880
# INFO:my_logger:Log message number 5881
# INFO:my_logger:Log message number 5882
# INFO:my_logger:Log message number 5883
# INFO:my_logger:Log message number 5884
# INFO:my_logger:Log message number 5885
# INFO:my_logger:Log message number 5886
# INFO:my_logger:Log message number 5887
# INFO:my_logger:Log message number 5888
# INFO:my_logger:Log message number 5889
# INFO:my_logger:Log message number 5890
# INFO:my_logger:Log message number 5891
# INFO:my_logger:Log message number 5892
# INFO:my_logger:Log message number 5893
# INFO:my_logger:Log message number 5894
# INFO:my_logger:Log message number 5895
# INFO:my_logger:Log message number 5896
# INFO:my_logger:Log message number 5897
# INFO:my_logger:Log message number 5898
# INFO:my_logger:Log message number 5899
# INFO:my_logger:Log message number 5900
# INFO:my_logger:Log message number 5901
# INFO:my_logger:Log message number 5902
# INFO:my_logger:Log message number 5903
# INFO:my_logger:Log message number 5904
# INFO:my_logger:Log message number 5905
# INFO:my_logger:Log message number 5906
# INFO:my_logger:Log message number 5907
# INFO:my_logger:Log message number 5908
# INFO:my_logger:Log message number 5909
# INFO:my_logger:Log message number 5910
# INFO:my_logger:Log message number 5911
# INFO:my_logger:Log message number 5912
# INFO:my_logger:Log message number 5913
# INFO:my_logger:Log message number 5914
# INFO:my_logger:Log message number 5915
# INFO:my_logger:Log message number 5916
# INFO:my_logger:Log message number 5917
# INFO:my_logger:Log message number 5918
# INFO:my_logger:Log message number 5919
# INFO:my_logger:Log message number 5920
# INFO:my_logger:Log message number 5921
# INFO:my_logger:Log message number 5922
# INFO:my_logger:Log message number 5923
# INFO:my_logger:Log message number 5924
# INFO:my_logger:Log message number 5925
# INFO:my_logger:Log message number 5926
# INFO:my_logger:Log message number 5927
# INFO:my_logger:Log message number 5928
# INFO:my_logger:Log message number 5929
# INFO:my_logger:Log message number 5930
# INFO:my_logger:Log message number 5931
# INFO:my_logger:Log message number 5932
# INFO:my_logger:Log message number 5933
# INFO:my_logger:Log message number 5934
# INFO:my_logger:Log message number 5935
# INFO:my_logger:Log message number 5936
# INFO:my_logger:Log message number 5937
# INFO:my_logger:Log message number 5938
# INFO:my_logger:Log message number 5939
# INFO:my_logger:Log message number 5940
# INFO:my_logger:Log message number 5941
# INFO:my_logger:Log message number 5942
# INFO:my_logger:Log message number 5943
# INFO:my_logger:Log message number 5944
# INFO:my_logger:Log message number 5945
# INFO:my_logger:Log message number 5946
# INFO:my_logger:Log message number 5947
# INFO:my_logger:Log message number 5948
# INFO:my_logger:Log message number 5949
# INFO:my_logger:Log message number 5950
# INFO:my_logger:Log message number 5951
# INFO:my_logger:Log message number 5952
# INFO:my_logger:Log message number 5953
# INFO:my_logger:Log message number 5954
# INFO:my_logger:Log message number 5955
# INFO:my_logger:Log message number 5956
# INFO:my_logger:Log message number 5957
# INFO:my_logger:Log message number 5958
# INFO:my_logger:Log message number 5959
# INFO:my_logger:Log message number 5960
# INFO:my_logger:Log message number 5961
# INFO:my_logger:Log message number 5962
# INFO:my_logger:Log message number 5963
# INFO:my_logger:Log message number 5964
# INFO:my_logger:Log message number 5965
# INFO:my_logger:Log message number 5966
# INFO:my_logger:Log message number 5967
# INFO:my_logger:Log message number 5968
# INFO:my_logger:Log message number 5969
# INFO:my_logger:Log message number 5970
# INFO:my_logger:Log message number 5971
# INFO:my_logger:Log message number 5972
# INFO:my_logger:Log message number 5973
# INFO:my_logger:Log message number 5974
# INFO:my_logger:Log message number 5975
# INFO:my_logger:Log message number 5976
# INFO:my_logger:Log message number 5977
# INFO:my_logger:Log message number 5978
# INFO:my_logger:Log message number 5979
# INFO:my_logger:Log message number 5980
# INFO:my_logger:Log message number 5981
# INFO:my_logger:Log message number 5982
# INFO:my_logger:Log message number 5983
# INFO:my_logger:Log message number 5984
# INFO:my_logger:Log message number 5985
# INFO:my_logger:Log message number 5986
# INFO:my_logger:Log message number 5987
# INFO:my_logger:Log message number 5988
# INFO:my_logger:Log message number 5989
# INFO:my_logger:Log message number 5990
# INFO:my_logger:Log message number 5991
# INFO:my_logger:Log message number 5992
# INFO:my_logger:Log message number 5993
# INFO:my_logger:Log message number 5994
# INFO:my_logger:Log message number 5995
# INFO:my_logger:Log message number 5996
# INFO:my_logger:Log message number 5997
# INFO:my_logger:Log message number 5998
# INFO:my_logger:Log message number 5999
# INFO:my_logger:Log message number 6000
# INFO:my_logger:Log message number 6001
# INFO:my_logger:Log message number 6002
# INFO:my_logger:Log message number 6003
# INFO:my_logger:Log message number 6004
# INFO:my_logger:Log message number 6005
# INFO:my_logger:Log message number 6006
# INFO:my_logger:Log message number 6007
# INFO:my_logger:Log message number 6008
# INFO:my_logger:Log message number 6009
# INFO:my_logger:Log message number 6010
# INFO:my_logger:Log message number 6011
# INFO:my_logger:Log message number 6012
# INFO:my_logger:Log message number 6013
# INFO:my_logger:Log message number 6014
# INFO:my_logger:Log message number 6015
# INFO:my_logger:Log message number 6016
# INFO:my_logger:Log message number 6017
# INFO:my_logger:Log message number 6018
# INFO:my_logger:Log message number 6019
# INFO:my_logger:Log message number 6020
# INFO:my_logger:Log message number 6021
# INFO:my_logger:Log message number 6022
# INFO:my_logger:Log message number 6023
# INFO:my_logger:Log message number 6024
# INFO:my_logger:Log message number 6025
# INFO:my_logger:Log message number 6026
# INFO:my_logger:Log message number 6027
# INFO:my_logger:Log message number 6028
# INFO:my_logger:Log message number 6029
# INFO:my_logger:Log message number 6030
# INFO:my_logger:Log message number 6031
# INFO:my_logger:Log message number 6032
# INFO:my_logger:Log message number 6033
# INFO:my_logger:Log message number 6034
# INFO:my_logger:Log message number 6035
# INFO:my_logger:Log message number 6036
# INFO:my_logger:Log message number 6037
# INFO:my_logger:Log message number 6038
# INFO:my_logger:Log message number 6039
# INFO:my_logger:Log message number 6040
# INFO:my_logger:Log message number 6041
# INFO:my_logger:Log message number 6042
# INFO:my_logger:Log message number 6043
# INFO:my_logger:Log message number 6044
# INFO:my_logger:Log message number 6045
# INFO:my_logger:Log message number 6046
# INFO:my_logger:Log message number 6047
# INFO:my_logger:Log message number 6048
# INFO:my_logger:Log message number 6049
# INFO:my_logger:Log message number 6050
# INFO:my_logger:Log message number 6051
# INFO:my_logger:Log message number 6052
# INFO:my_logger:Log message number 6053
# INFO:my_logger:Log message number 6054
# INFO:my_logger:Log message number 6055
# INFO:my_logger:Log message number 6056
# INFO:my_logger:Log message number 6057
# INFO:my_logger:Log message number 6058
# INFO:my_logger:Log message number 6059
# INFO:my_logger:Log message number 6060
# INFO:my_logger:Log message number 6061
# INFO:my_logger:Log message number 6062
# INFO:my_logger:Log message number 6063
# INFO:my_logger:Log message number 6064
# INFO:my_logger:Log message number 6065
# INFO:my_logger:Log message number 6066
# INFO:my_logger:Log message number 6067
# INFO:my_logger:Log message number 6068
# INFO:my_logger:Log message number 6069
# INFO:my_logger:Log message number 6070
# INFO:my_logger:Log message number 6071
# INFO:my_logger:Log message number 6072
# INFO:my_logger:Log message number 6073
# INFO:my_logger:Log message number 6074
# INFO:my_logger:Log message number 6075
# INFO:my_logger:Log message number 6076
# INFO:my_logger:Log message number 6077
# INFO:my_logger:Log message number 6078
# INFO:my_logger:Log message number 6079
# INFO:my_logger:Log message number 6080
# INFO:my_logger:Log message number 6081
# INFO:my_logger:Log message number 6082
# INFO:my_logger:Log message number 6083
# INFO:my_logger:Log message number 6084
# INFO:my_logger:Log message number 6085
# INFO:my_logger:Log message number 6086
# INFO:my_logger:Log message number 6087
# INFO:my_logger:Log message number 6088
# INFO:my_logger:Log message number 6089
# INFO:my_logger:Log message number 6090
# INFO:my_logger:Log message number 6091
# INFO:my_logger:Log message number 6092
# INFO:my_logger:Log message number 6093
# INFO:my_logger:Log message number 6094
# INFO:my_logger:Log message number 6095
# INFO:my_logger:Log message number 6096
# INFO:my_logger:Log message number 6097
# INFO:my_logger:Log message number 6098
# INFO:my_logger:Log message number 6099
# INFO:my_logger:Log message number 6100
# INFO:my_logger:Log message number 6101
# INFO:my_logger:Log message number 6102
# INFO:my_logger:Log message number 6103
# INFO:my_logger:Log message number 6104
# INFO:my_logger:Log message number 6105
# INFO:my_logger:Log message number 6106
# INFO:my_logger:Log message number 6107
# INFO:my_logger:Log message number 6108
# INFO:my_logger:Log message number 6109
# INFO:my_logger:Log message number 6110
# INFO:my_logger:Log message number 6111
# INFO:my_logger:Log message number 6112
# INFO:my_logger:Log message number 6113
# INFO:my_logger:Log message number 6114
# INFO:my_logger:Log message number 6115
# INFO:my_logger:Log message number 6116
# INFO:my_logger:Log message number 6117
# INFO:my_logger:Log message number 6118
# INFO:my_logger:Log message number 6119
# INFO:my_logger:Log message number 6120
# INFO:my_logger:Log message number 6121
# INFO:my_logger:Log message number 6122
# INFO:my_logger:Log message number 6123
# INFO:my_logger:Log message number 6124
# INFO:my_logger:Log message number 6125
# INFO:my_logger:Log message number 6126
# INFO:my_logger:Log message number 6127
# INFO:my_logger:Log message number 6128
# INFO:my_logger:Log message number 6129
# INFO:my_logger:Log message number 6130
# INFO:my_logger:Log message number 6131
# INFO:my_logger:Log message number 6132
# INFO:my_logger:Log message number 6133
# INFO:my_logger:Log message number 6134
# INFO:my_logger:Log message number 6135
# INFO:my_logger:Log message number 6136
# INFO:my_logger:Log message number 6137
# INFO:my_logger:Log message number 6138
# INFO:my_logger:Log message number 6139
# INFO:my_logger:Log message number 6140
# INFO:my_logger:Log message number 6141
# INFO:my_logger:Log message number 6142
# INFO:my_logger:Log message number 6143
# INFO:my_logger:Log message number 6144
# INFO:my_logger:Log message number 6145
# INFO:my_logger:Log message number 6146
# INFO:my_logger:Log message number 6147
# INFO:my_logger:Log message number 6148
# INFO:my_logger:Log message number 6149
# INFO:my_logger:Log message number 6150
# INFO:my_logger:Log message number 6151
# INFO:my_logger:Log message number 6152
# INFO:my_logger:Log message number 6153
# INFO:my_logger:Log message number 6154
# INFO:my_logger:Log message number 6155
# INFO:my_logger:Log message number 6156
# INFO:my_logger:Log message number 6157
# INFO:my_logger:Log message number 6158
# INFO:my_logger:Log message number 6159
# INFO:my_logger:Log message number 6160
# INFO:my_logger:Log message number 6161
# INFO:my_logger:Log message number 6162
# INFO:my_logger:Log message number 6163
# INFO:my_logger:Log message number 6164
# INFO:my_logger:Log message number 6165
# INFO:my_logger:Log message number 6166
# INFO:my_logger:Log message number 6167
# INFO:my_logger:Log message number 6168
# INFO:my_logger:Log message number 6169
# INFO:my_logger:Log message number 6170
# INFO:my_logger:Log message number 6171
# INFO:my_logger:Log message number 6172
# INFO:my_logger:Log message number 6173
# INFO:my_logger:Log message number 6174
# INFO:my_logger:Log message number 6175
# INFO:my_logger:Log message number 6176
# INFO:my_logger:Log message number 6177
# INFO:my_logger:Log message number 6178
# INFO:my_logger:Log message number 6179
# INFO:my_logger:Log message number 6180
# INFO:my_logger:Log message number 6181
# INFO:my_logger:Log message number 6182
# INFO:my_logger:Log message number 6183
# INFO:my_logger:Log message number 6184
# INFO:my_logger:Log message number 6185
# INFO:my_logger:Log message number 6186
# INFO:my_logger:Log message number 6187
# INFO:my_logger:Log message number 6188
# INFO:my_logger:Log message number 6189
# INFO:my_logger:Log message number 6190
# INFO:my_logger:Log message number 6191
# INFO:my_logger:Log message number 6192
# INFO:my_logger:Log message number 6193
# INFO:my_logger:Log message number 6194
# INFO:my_logger:Log message number 6195
# INFO:my_logger:Log message number 6196
# INFO:my_logger:Log message number 6197
# INFO:my_logger:Log message number 6198
# INFO:my_logger:Log message number 6199
# INFO:my_logger:Log message number 6200
# INFO:my_logger:Log message number 6201
# INFO:my_logger:Log message number 6202
# INFO:my_logger:Log message number 6203
# INFO:my_logger:Log message number 6204
# INFO:my_logger:Log message number 6205
# INFO:my_logger:Log message number 6206
# INFO:my_logger:Log message number 6207
# INFO:my_logger:Log message number 6208
# INFO:my_logger:Log message number 6209
# INFO:my_logger:Log message number 6210
# INFO:my_logger:Log message number 6211
# INFO:my_logger:Log message number 6212
# INFO:my_logger:Log message number 6213
# INFO:my_logger:Log message number 6214
# INFO:my_logger:Log message number 6215
# INFO:my_logger:Log message number 6216
# INFO:my_logger:Log message number 6217
# INFO:my_logger:Log message number 6218
# INFO:my_logger:Log message number 6219
# INFO:my_logger:Log message number 6220
# INFO:my_logger:Log message number 6221
# INFO:my_logger:Log message number 6222
# INFO:my_logger:Log message number 6223
# INFO:my_logger:Log message number 6224
# INFO:my_logger:Log message number 6225
# INFO:my_logger:Log message number 6226
# INFO:my_logger:Log message number 6227
# INFO:my_logger:Log message number 6228
# ...
# INFO:my_logger:Log message number 9590
# INFO:my_logger:Log message number 9591
# INFO:my_logger:Log message number 9592
# INFO:my_logger:Log message number 9593
# INFO:my_logger:Log message number 9594
# INFO:my_logger:Log message number 9595
# INFO:my_logger:Log message number 9596
# INFO:my_logger:Log message number 9597
# INFO:my_logger:Log message number 9598
# INFO:my_logger:Log message number 9599
# INFO:my_logger:Log message number 9600
# INFO:my_logger:Log message number 9601
# INFO:my_logger:Log message number 9602
# INFO:my_logger:Log message number 9603
# INFO:my_logger:Log message number 9604
# INFO:my_logger:Log message number 9605
# INFO:my_logger:Log message number 9606
# INFO:my_logger:Log message number 9607
# INFO:my_logger:Log message number 9608
# INFO:my_logger:Log message number 9609
# INFO:my_logger:Log message number 9610
# INFO:my_logger:Log message number 9611
# INFO:my_logger:Log message number 9612
# INFO:my_logger:Log message number 9613
# INFO:my_logger:Log message number 9614
# INFO:my_logger:Log message number 9615
# INFO:my_logger:Log message number 9616
# INFO:my_logger:Log message number 9617
# INFO:my_logger:Log message number 9618
# INFO:my_logger:Log message number 9619
# INFO:my_logger:Log message number 9620
# INFO:my_logger:Log message number 9621
# INFO:my_logger:Log message number 9622
# INFO:my_logger:Log message number 9623
# INFO:my_logger:Log message number 9624
# INFO:my_logger:Log message number 9625
# INFO:my_logger:Log message number 9626
# INFO:my_logger:Log message number 9627
# INFO:my_logger:Log message number 9628
# INFO:my_logger:Log message number 9629
# INFO:my_logger:Log message number 9630
# INFO:my_logger:Log message number 9631
# INFO:my_logger:Log message number 9632
# INFO:my_logger:Log message number 9633
# INFO:my_logger:Log message number 9634
# INFO:my_logger:Log message number 9635
# INFO:my_logger:Log message number 9636
# INFO:my_logger:Log message number 9637
# INFO:my_logger:Log message number 9638
# INFO:my_logger:Log message number 9639
# INFO:my_logger:Log message number 9640
# INFO:my_logger:Log message number 9641
# INFO:my_logger:Log message number 9642
# INFO:my_logger:Log message number 9643
# INFO:my_logger:Log message number 9644
# INFO:my_logger:Log message number 9645
# INFO:my_logger:Log message number 9646
# INFO:my_logger:Log message number 9647
# INFO:my_logger:Log message number 9648
# INFO:my_logger:Log message number 9649
# INFO:my_logger:Log message number 9650
# INFO:my_logger:Log message number 9651
# INFO:my_logger:Log message number 9652
# INFO:my_logger:Log message number 9653
# INFO:my_logger:Log message number 9654
# INFO:my_logger:Log message number 9655
# INFO:my_logger:Log message number 9656
# INFO:my_logger:Log message number 9657
# INFO:my_logger:Log message number 9658
# INFO:my_logger:Log message number 9659
# INFO:my_logger:Log message number 9660
# INFO:my_logger:Log message number 9661
# INFO:my_logger:Log message number 9662
# INFO:my_logger:Log message number 9663
# INFO:my_logger:Log message number 9664
# INFO:my_logger:Log message number 9665
# INFO:my_logger:Log message number 9666
# INFO:my_logger:Log message number 9667
# INFO:my_logger:Log message number 9668
# INFO:my_logger:Log message number 9669
# INFO:my_logger:Log message number 9670
# INFO:my_logger:Log message number 9671
# INFO:my_logger:Log message number 9672
# INFO:my_logger:Log message number 9673
# INFO:my_logger:Log message number 9674
# INFO:my_logger:Log message number 9675
# INFO:my_logger:Log message number 9676
# INFO:my_logger:Log message number 9677
# INFO:my_logger:Log message number 9678
# INFO:my_logger:Log message number 9679
# INFO:my_logger:Log message number 9680
# INFO:my_logger:Log message number 9681
# INFO:my_logger:Log message number 9682
# INFO:my_logger:Log message number 9683
# INFO:my_logger:Log message number 9684
# INFO:my_logger:Log message number 9685
# INFO:my_logger:Log message number 9686
# INFO:my_logger:Log message number 9687
# INFO:my_logger:Log message number 9688
# INFO:my_logger:Log message number 9689
# INFO:my_logger:Log message number 9690
# INFO:my_logger:Log message number 9691
# INFO:my_logger:Log message number 9692
# INFO:my_logger:Log message number 9693
# INFO:my_logger:Log message number 9694
# INFO:my_logger:Log message number 9695
# INFO:my_logger:Log message number 9696
# INFO:my_logger:Log message number 9697
# INFO:my_logger:Log message number 9698
# INFO:my_logger:Log message number 9699
# INFO:my_logger:Log message number 9700
# INFO:my_logger:Log message number 9701
# INFO:my_logger:Log message number 9702
# INFO:my_logger:Log message number 9703
# INFO:my_logger:Log message number 9704
# INFO:my_logger:Log message number 9705
# INFO:my_logger:Log message number 9706
# INFO:my_logger:Log message number 9707
# INFO:my_logger:Log message number 9708
# INFO:my_logger:Log message number 9709
# INFO:my_logger:Log message number 9710
# INFO:my_logger:Log message number 9711
# INFO:my_logger:Log message number 9712
# INFO:my_logger:Log message number 9713
# INFO:my_logger:Log message number 9714
# INFO:my_logger:Log message number 9715
# INFO:my_logger:Log message number 9716
# INFO:my_logger:Log message number 9717
# INFO:my_logger:Log message number 9718
# INFO:my_logger:Log message number 9719
# INFO:my_logger:Log message number 9720
# INFO:my_logger:Log message number 9721
# INFO:my_logger:Log message number 9722
# INFO:my_logger:Log message number 9723
# INFO:my_logger:Log message number 9724
# INFO:my_logger:Log message number 9725
# INFO:my_logger:Log message number 9726
# INFO:my_logger:Log message number 9727
# INFO:my_logger:Log message number 9728
# INFO:my_logger:Log message number 9729
# INFO:my_logger:Log message number 9730
# INFO:my_logger:Log message number 9731
# INFO:my_logger:Log message number 9732
# INFO:my_logger:Log message number 9733
# INFO:my_logger:Log message number 9734
# INFO:my_logger:Log message number 9735
# INFO:my_logger:Log message number 9736
# INFO:my_logger:Log message number 9737
# INFO:my_logger:Log message number 9738
# INFO:my_logger:Log message number 9739
# INFO:my_logger:Log message number 9740
# INFO:my_logger:Log message number 9741
# INFO:my_logger:Log message number 9742
# INFO:my_logger:Log message number 9743
# INFO:my_logger:Log message number 9744
# INFO:my_logger:Log message number 9745
# INFO:my_logger:Log message number 9746
# INFO:my_logger:Log message number 9747
# INFO:my_logger:Log message number 9748
# INFO:my_logger:Log message number 9749
# INFO:my_logger:Log message number 9750
# INFO:my_logger:Log message number 9751
# INFO:my_logger:Log message number 9752
# INFO:my_logger:Log message number 9753
# INFO:my_logger:Log message number 9754
# INFO:my_logger:Log message number 9755
# INFO:my_logger:Log message number 9756
# INFO:my_logger:Log message number 9757
# INFO:my_logger:Log message number 9758
# INFO:my_logger:Log message number 9759
# INFO:my_logger:Log message number 9760
# INFO:my_logger:Log message number 9761
# INFO:my_logger:Log message number 9762
# INFO:my_logger:Log message number 9763
# INFO:my_logger:Log message number 9764
# INFO:my_logger:Log message number 9765
# INFO:my_logger:Log message number 9766
# INFO:my_logger:Log message number 9767
# INFO:my_logger:Log message number 9768
# INFO:my_logger:Log message number 9769
# INFO:my_logger:Log message number 9770
# INFO:my_logger:Log message number 9771
# INFO:my_logger:Log message number 9772
# INFO:my_logger:Log message number 9773
# INFO:my_logger:Log message number 9774
# INFO:my_logger:Log message number 9775
# INFO:my_logger:Log message number 9776
# INFO:my_logger:Log message number 9777
# INFO:my_logger:Log message number 9778
# INFO:my_logger:Log message number 9779
# INFO:my_logger:Log message number 9780
# INFO:my_logger:Log message number 9781
# INFO:my_logger:Log message number 9782
# INFO:my_logger:Log message number 9783
# INFO:my_logger:Log message number 9784
# INFO:my_logger:Log message number 9785
# INFO:my_logger:Log message number 9786
# INFO:my_logger:Log message number 9787
# INFO:my_logger:Log message number 9788
# INFO:my_logger:Log message number 9789
# INFO:my_logger:Log message number 9790
# INFO:my_logger:Log message number 9791
# INFO:my_logger:Log message number 9792
# INFO:my_logger:Log message number 9793
# INFO:my_logger:Log message number 9794
# INFO:my_logger:Log message number 9795
# INFO:my_logger:Log message number 9796
# INFO:my_logger:Log message number 9797
# INFO:my_logger:Log message number 9798
# INFO:my_logger:Log message number 9799
# INFO:my_logger:Log message number 9800
# INFO:my_logger:Log message number 9801
# INFO:my_logger:Log message number 9802
# INFO:my_logger:Log message number 9803
# INFO:my_logger:Log message number 9804
# INFO:my_logger:Log message number 9805
# INFO:my_logger:Log message number 9806
# INFO:my_logger:Log message number 9807
# INFO:my_logger:Log message number 9808
# INFO:my_logger:Log message number 9809
# INFO:my_logger:Log message number 9810
# INFO:my_logger:Log message number 9811
# INFO:my_logger:Log message number 9812
# INFO:my_logger:Log message number 9813
# INFO:my_logger:Log message number 9814
# INFO:my_logger:Log message number 9815
# INFO:my_logger:Log message number 9816
# INFO:my_logger:Log message number 9817
# INFO:my_logger:Log message number 9818
# INFO:my_logger:Log message number 9819
# INFO:my_logger:Log message number 9820
# INFO:my_logger:Log message number 9821
# INFO:my_logger:Log message number 9822
# INFO:my_logger:Log message number 9823
# INFO:my_logger:Log message number 9824
# INFO:my_logger:Log message number 9825
# INFO:my_logger:Log message number 9826
# INFO:my_logger:Log message number 9827
# INFO:my_logger:Log message number 9828
# INFO:my_logger:Log message number 9829
# INFO:my_logger:Log message number 9830
# INFO:my_logger:Log message number 9831
# INFO:my_logger:Log message number 9832
# INFO:my_logger:Log message number 9833
# INFO:my_logger:Log message number 9834
# INFO:my_logger:Log message number 9835
# INFO:my_logger:Log message number 9836
# INFO:my_logger:Log message number 9837
# INFO:my_logger:Log message number 9838
# INFO:my_logger:Log message number 9839
# INFO:my_logger:Log message number 9840
# INFO:my_logger:Log message number 9841
# INFO:my_logger:Log message number 9842
# INFO:my_logger:Log message number 9843
# INFO:my_logger:Log message number 9844
# INFO:my_logger:Log message number 9845
# INFO:my_logger:Log message number 9846
# INFO:my_logger:Log message number 9847
# INFO:my_logger:Log message number 9848
# INFO:my_logger:Log message number 9849
# INFO:my_logger:Log message number 9850
# INFO:my_logger:Log message number 9851
# INFO:my_logger:Log message number 9852
# INFO:my_logger:Log message number 9853
# INFO:my_logger:Log message number 9854
# INFO:my_logger:Log message number 9855
# INFO:my_logger:Log message number 9856
# INFO:my_logger:Log message number 9857
# INFO:my_logger:Log message number 9858
# INFO:my_logger:Log message number 9859
# INFO:my_logger:Log message number 9860
# INFO:my_logger:Log message number 9861
# INFO:my_logger:Log message number 9862
# INFO:my_logger:Log message number 9863
# INFO:my_logger:Log message number 9864
# INFO:my_logger:Log message number 9865
# INFO:my_logger:Log message number 9866
# INFO:my_logger:Log message number 9867
# INFO:my_logger:Log message number 9868
# INFO:my_logger:Log message number 9869
# INFO:my_logger:Log message number 9870
# INFO:my_logger:Log message number 9871
# INFO:my_logger:Log message number 9872
# INFO:my_logger:Log message number 9873
# INFO:my_logger:Log message number 9874
# INFO:my_logger:Log message number 9875
# INFO:my_logger:Log message number 9876
# INFO:my_logger:Log message number 9877
# INFO:my_logger:Log message number 9878
# INFO:my_logger:Log message number 9879
# INFO:my_logger:Log message number 9880
# INFO:my_logger:Log message number 9881
# INFO:my_logger:Log message number 9882
# INFO:my_logger:Log message number 9883
# INFO:my_logger:Log message number 9884
# INFO:my_logger:Log message number 9885
# INFO:my_logger:Log message number 9886
# INFO:my_logger:Log message number 9887
# INFO:my_logger:Log message number 9888
# INFO:my_logger:Log message number 9889
# INFO:my_logger:Log message number 9890
# INFO:my_logger:Log message number 9891
# INFO:my_logger:Log message number 9892
# INFO:my_logger:Log message number 9893
# INFO:my_logger:Log message number 9894
# INFO:my_logger:Log message number 9895
# INFO:my_logger:Log message number 9896
# INFO:my_logger:Log message number 9897
# INFO:my_logger:Log message number 9898
# INFO:my_logger:Log message number 9899
# INFO:my_logger:Log message number 9900
# INFO:my_logger:Log message number 9901
# INFO:my_logger:Log message number 9902
# INFO:my_logger:Log message number 9903
# INFO:my_logger:Log message number 9904
# INFO:my_logger:Log message number 9905
# INFO:my_logger:Log message number 9906
# INFO:my_logger:Log message number 9907
# INFO:my_logger:Log message number 9908
# INFO:my_logger:Log message number 9909
# INFO:my_logger:Log message number 9910
# INFO:my_logger:Log message number 9911
# INFO:my_logger:Log message number 9912
# INFO:my_logger:Log message number 9913
# INFO:my_logger:Log message number 9914
# INFO:my_logger:Log message number 9915
# INFO:my_logger:Log message number 9916
# INFO:my_logger:Log message number 9917
# INFO:my_logger:Log message number 9918
# INFO:my_logger:Log message number 9919
# INFO:my_logger:Log message number 9920
# INFO:my_logger:Log message number 9921
# INFO:my_logger:Log message number 9922
# INFO:my_logger:Log message number 9923
# INFO:my_logger:Log message number 9924
# INFO:my_logger:Log message number 9925
# INFO:my_logger:Log message number 9926
# INFO:my_logger:Log message number 9927
# INFO:my_logger:Log message number 9928
# INFO:my_logger:Log message number 9929
# INFO:my_logger:Log message number 9930
# INFO:my_logger:Log message number 9931
# INFO:my_logger:Log message number 9932
# INFO:my_logger:Log message number 9933
# INFO:my_logger:Log message number 9934
# INFO:my_logger:Log message number 9935
# INFO:my_logger:Log message number 9936
# INFO:my_logger:Log message number 9937
# INFO:my_logger:Log message number 9938
# INFO:my_logger:Log message number 9939
# INFO:my_logger:Log message number 9940
# INFO:my_logger:Log message number 9941
# INFO:my_logger:Log message number 9942
# INFO:my_logger:Log message number 9943
# INFO:my_logger:Log message number 9944
# INFO:my_logger:Log message number 9945
# INFO:my_logger:Log message number 9946
# INFO:my_logger:Log message number 9947
# INFO:my_logger:Log message number 9948
# INFO:my_logger:Log message number 9949
# INFO:my_logger:Log message number 9950
# INFO:my_logger:Log message number 9951
# INFO:my_logger:Log message number 9952
# INFO:my_logger:Log message number 9953
# INFO:my_logger:Log message number 9954
# INFO:my_logger:Log message number 9955
# INFO:my_logger:Log message number 9956
# INFO:my_logger:Log message number 9957
# INFO:my_logger:Log message number 9958
# INFO:my_logger:Log message number 9959
# INFO:my_logger:Log message number 9960
# INFO:my_logger:Log message number 9961
# INFO:my_logger:Log message number 9962
# INFO:my_logger:Log message number 9963
# INFO:my_logger:Log message number 9964
# INFO:my_logger:Log message number 9965
# INFO:my_logger:Log message number 9966
# INFO:my_logger:Log message number 9967
# INFO:my_logger:Log message number 9968
# INFO:my_logger:Log message number 9969
# INFO:my_logger:Log message number 9970
# INFO:my_logger:Log message number 9971
# INFO:my_logger:Log message number 9972
# INFO:my_logger:Log message number 9973
# INFO:my_logger:Log message number 9974
# INFO:my_logger:Log message number 9975
# INFO:my_logger:Log message number 9976
# INFO:my_logger:Log message number 9977
# INFO:my_logger:Log message number 9978
# INFO:my_logger:Log message number 9979
# INFO:my_logger:Log message number 9980
# INFO:my_logger:Log message number 9981
# INFO:my_logger:Log message number 9982
# INFO:my_logger:Log message number 9983
# INFO:my_logger:Log message number 9984
# INFO:my_logger:Log message number 9985
# INFO:my_logger:Log message number 9986
# INFO:my_logger:Log message number 9987
# INFO:my_logger:Log message number 9988
# INFO:my_logger:Log message number 9989
# INFO:my_logger:Log message number 9990
# INFO:my_logger:Log message number 9991
# INFO:my_logger:Log message number 9992
# INFO:my_logger:Log message number 9993
# INFO:my_logger:Log message number 9994
# INFO:my_logger:Log message number 9995
# INFO:my_logger:Log message number 9996
# INFO:my_logger:Log message number 9997
# INFO:my_logger:Log message number 9998
# INFO:my_logger:Log message number 9999

# %%
19. # Write a program that handles both IndexError and KeyError using a try-except block?

# %%
def access_element(data, index=None, key=None):
    try:
        if index is not None:
            # Attempt to access an element by index (potential IndexError)
            value = data[index]
            print(f"Value at index {index}: {value}")
        elif key is not None:
            # Attempt to access an element by key (potential KeyError)
            value = data[key]
            print(f"Value for key '{key}': {value}")
        else:
            print("No index or key provided.")

    except IndexError:
        print(f"Error: Invalid index '{index}'. Index out of range.")
    except KeyError:
        print(f"Error: Key '{key}' not found in the dictionary.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage:

# List example (IndexError)
my_list = [10, 20, 30]
access_element(my_list, index=5) # This will cause an IndexError

# Dictionary example (KeyError)
my_dict = {"a": 1, "b": 2}
access_element(my_dict, key="c") # This will cause a KeyError

# Valid access examples
access_element(my_list, index=1)
access_element(my_dict, key="a")
# Out:
# Error: Invalid index '5'. Index out of range.
# Error: Key 'c' not found in the dictionary.
# Value at index 1: 20
# Value for key 'a': 1

# %%
20. # How would you open a file and read its contents using a context manager in Python?

# %%
try:
    # Specify the file name
    file_name = 'my_file.txt'

    # Open the file using a context manager ('with' statement)
    with open(file_name, 'r') as file:
        # Read the entire content of the file
        content = file.read()

        # Print the content
        print(f"Content of '{file_name}':")
        print(content)

except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Content of 'my_file.txt':
#
# This line is appended to the file.

# %%
21. # Write a Python program that reads a file and prints the number of occurrences of a specific word?

# %%
import re

def count_word_occurrences(file_path, word):
    """
    Reads a file and counts the occurrences of a specific word (case-insensitive).

    Args:
        file_path (str): The path to the file.
        word (str): The word to count.

    Returns:
        int: The number of occurrences of the word in the file.
    """
    count = 0
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the entire content of the file
            content = file.read()

            # Use regular expression to find the word, ignoring case
            # \b ensures that we match whole words only
            word_pattern = r'\b' + re.escape(word) + r'\b'
            matches = re.findall(word_pattern, content, re.IGNORECASE)

            count = len(matches)

    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
        return -1 # Indicate an error
    except Exception as e:
        print(f"An error occurred: {e}")
        return -1 # Indicate an error

    return count

# Example usage:
file_name = 'my_file.txt'  # Replace with your file name
word_to_find = 'file'      # Replace with the word you want to count

occurrence_count = count_word_occurrences(file_name, word_to_find)

if occurrence_count != -1:
    print(f"The word '{word_to_find}' appears {occurrence_count} times in '{file_name}'.")
# Out:
# The word 'file' appears 1 times in 'my_file.txt'.

# %%
22. # How can you check if a file is empty before attempting to read its contents?

# %%
import os

def is_file_empty(file_path):
    """
    Checks if a file exists and is empty.

    Args:
        file_path (str): The path to the file.

    Returns:
        bool: True if the file exists and is empty, False otherwise.
    """
    if not os.path.exists(file_path):
        print(f"Error: The file '{file_path}' does not exist.")
        return False # File doesn't exist, so not empty

    if os.path.getsize(file_path) == 0:
        print(f"The file '{file_path}' is empty.")
        return True
    else:
        print(f"The file '{file_path}' is not empty.")
        return False

# Example usage:
file_name_existing = 'my_file.txt'  # Assuming this file exists and has content
file_name_empty = 'empty_file.txt' # Let's create an empty file for testing

# Create an empty file for demonstration
with open(file_name_empty, 'w') as f:
    pass # This creates an empty file

is_file_empty(file_name_existing)
is_file_empty(file_name_empty)
is_file_empty('non_existent_file.txt') # Test with a non-existent file

# Clean up the empty file
os.remove(file_name_empty)
# Out:
# The file 'my_file.txt' is not empty.
# The file 'empty_file.txt' is empty.
# Error: The file 'non_existent_file.txt' does not exist.

# %%
23. # Write a Python program that writes to a log file when an error occurs during file handling?

# %%
import logging
import os

# Configure logging to write to a file
logging.basicConfig(filename='file_handling_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def read_file_with_error_logging(file_path):
    """
    Attempts to read a file and logs an error if file handling fails.

    Args:
        file_path (str): The path to the file to read.
    """
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print(f"Successfully read content from '{file_path}':")
            print(content)
    except FileNotFoundError:
        error_message = f"Error: File not found at '{file_path}'."
        logging.error(error_message)
        print(error_message + " This error has been logged.")
    except IOError as e:
        error_message = f"Error: An I/O error occurred while reading '{file_path}': {e}"
        logging.error(error_message)
        print(error_message + " This error has been logged.")
    except Exception as e:
        error_message = f"Error: An unexpected error occurred while handling '{file_path}': {e}"
        logging.error(error_message)
        print(error_message + " This error has been logged.")

# Example usage:
# Attempt to read a file that exists
read_file_with_error_logging('my_file.txt')

# Attempt to read a file that does NOT exist
read_file_with_error_logging('non_existent_file_for_logging.txt')

print("\nCheck 'file_handling_errors.log' for logged errors.")
# Out:
# ERROR:root:Error: File not found at 'non_existent_file_for_logging.txt'.
# Successfully read content from 'my_file.txt':
#
# This line is appended to the file.
# Error: File not found at 'non_existent_file_for_logging.txt'. This error has been logged.
#
# Check 'file_handling_errors.log' for logged errors.
